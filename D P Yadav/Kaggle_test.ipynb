# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import numpy as np
import pickle
import cv2
from os import listdir
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
import tensorflow as tf
import gc
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import VGG16, DenseNet169
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Activation, BatchNormalization, Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,TensorBoard,TerminateOnNaN, LearningRateScheduler
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
from tensorflow.keras.layers import Lambda, Reshape, DepthwiseConv2D, ZeroPadding2D, Add, MaxPooling2D,Activation, Flatten, Conv2D, Dense, Input, Dropout, Concatenate, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from imutils import paths
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os
#from classification_models.tfkeras import Classifiers
from datetime import datetime
# %load_ext tensorboard

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('acc') >= 0.96):   
            print("Reached 95% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
EPOCHS =20
INIT_LR = 3e-3
BS =32
default_image_size = tuple((224, 224))
image_size = 0
width=224
height=224
depth=3
train_dir=r"D:\kaggle\train\Augmented"
#valid_dir=r"C:\Users\Glau\Desktop\DP\Pediastrum_cnn\Test"
train_folder=listdir(train_dir)
#valid_folder=listdir(valid_dir)

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
callbacks = MyCustomCallback()

# %%
train_image_list, train_image_label=[],[]
for disease_folder in train_folder:
    print(f"processing {disease_folder} ...")
    disease_img_folder= listdir(f"{train_dir}/{disease_folder}")
    #print(disease_img_folder)
    for disease_img in disease_img_folder:
    #for disease_img in disease_img_folder[: : 2]:    
        image_directory = f"{train_dir}/{disease_folder}/{disease_img}"
        if image_directory.endswith(".jpeg") == True or image_directory.endswith(".jpg") == True or  image_directory.endswith(".png") == True:
            train_image_list.append(convert_image_to_array(image_directory))
            train_image_label.append(disease_folder)
print("[INFO] Image loading completed")
# Out:
# processing 0 ...
# processing 1 ...
# processing 2 ...
# processing 3 ...
# processing 4 ...
# [INFO] Image loading completed

# %%
print(len(train_image_label))
# Out:
# 30000

# %%
label_binarizer = LabelBinarizer()
bin_train_image_labels = label_binarizer.fit_transform(train_image_label)
#bin_valid_image_labels = label_binarizer.fit_transform(valid_image_label)
pickle.dump(label_binarizer,open('Label_Instance_burn_label415.pk', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(len(bin_train_image_labels))
# Out:
# 30000

# %%
np_train_image_list = np.array(train_image_list, dtype=np.float32) / 255.0

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

# %%
# coding: utf8
from tensorflow.keras import layers
from tensorflow.keras import models


#
# image dimensions
#

img_height = 224
img_width = 224
img_channels = 3

#
# network params
#

cardinality = 32


def residual_network(x):
    """
    ResNeXt by default. For ResNet set `cardinality` = 1 above.
    
    """
    def add_common_layers(y):
        y = layers.BatchNormalization()(y)
        y = layers.LeakyReLU()(y)

        return y

    def grouped_convolution(y, nb_channels, _strides):
        # when `cardinality` == 1 this is just a standard convolution
        if cardinality == 1:
            return layers.Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
        
        assert not nb_channels % cardinality
        _d = nb_channels // cardinality

        # in a grouped convolution layer, input and output channels are divided into `cardinality` groups,
        # and convolutions are separately performed within each group
        groups = []
        for j in range(cardinality):
            group = layers.Lambda(lambda z: z[:, :, :, j * _d:j * _d + _d])(y)
            groups.append(layers.Conv2D(_d, kernel_size=(3, 3), strides=_strides, padding='same')(group))
            
        # the grouped convolutional layer concatenates them as the outputs of the layer
        y = layers.concatenate(groups)

        return y

    def residual_block(y, nb_channels_in, nb_channels_out, _strides=(1, 1), _project_shortcut=False):
        """
        Our network consists of a stack of residual blocks. These blocks have the same topology,
        and are subject to two simple rules:

        - If producing spatial maps of the same size, the blocks share the same hyper-parameters (width and filter sizes).
        - Each time the spatial map is down-sampled by a factor of 2, the width of the blocks is multiplied by a factor of 2.
        """
        shortcut = y

        # we modify the residual building block as a bottleneck design to make the network more economical
        y = layers.Conv2D(nb_channels_in, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        y = add_common_layers(y)

        # ResNeXt (identical to ResNet when `cardinality` == 1)
        y = grouped_convolution(y, nb_channels_in, _strides=_strides)
        y = add_common_layers(y)

        y = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        # batch normalization is employed after aggregating the transformations and before adding to the shortcut
        y = layers.BatchNormalization()(y)

        # identity shortcuts used directly when the input and output are of the same dimensions
        if _project_shortcut or _strides != (1, 1):
            # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
            # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
            shortcut = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        y = layers.add([shortcut, y])

        # relu is performed right after each batch normalization,
        # expect for the output of the block where relu is performed after the adding to the shortcut
        y = layers.LeakyReLU()(y)

        return y

    # conv1
    x = layers.Conv2D(256, kernel_size=(5, 5), strides=(2, 2), padding='same')(x)
    x = add_common_layers(x)

    # conv2
    x = layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    for i in range(3):#3
        project_shortcut = True if i == 0 else False
        x = residual_block(x, 64, 128, _project_shortcut=project_shortcut)

    # conv3
    for i in range(4):#4
        # down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 128, 256, _strides=strides)

    # conv4
    for i in range(6):#6
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 256, 512, _strides=strides)

    # conv5
    for i in range(3):#3
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 512, 2048, _strides=strides)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(5,activation='softmax')(x)

    return x


image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
network_output = residual_network(image_tensor)
  
model = models.Model(inputs=[image_tensor], outputs=[network_output])
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 256 19456       input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 256 1024        conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 112, 112, 256 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 256)  0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   16448       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 56, 56, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 2)    38          lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 2)    38          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 2)    38          lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 2)    38          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 2)    38          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 2)    38          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 2)    38          lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 2)    38          lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 2)    38          lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 2)    38          lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 2)    38          lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 2)    38          lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 2)    38          lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 2)    38          lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 2)    38          lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 2)    38          lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 2)    38          lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 2)    38          lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 2)    38          lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 2)    38          lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 2)    38          lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 2)    38          lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 2)    38          lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 2)    38          lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 2)    38          lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 2)    38          lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 2)    38          lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 2)    38          lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 2)    38          lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 2)    38          lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 2)    38          lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 56, 56, 2)    38          lambda_31[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 64)   0           conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 64)   256         concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 56, 56, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 128)  32896       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 56, 56, 128)  8320        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 128)  0           batch_normalization_4[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 56, 56, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 56, 56, 64)   8256        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 56, 56, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 56, 56, 2)    38          lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 2)    38          lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 2)    38          lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 56, 56, 2)    38          lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 56, 56, 2)    38          lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 56, 56, 2)    38          lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 56, 56, 2)    38          lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 56, 56, 2)    38          lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 56, 56, 2)    38          lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 56, 56, 2)    38          lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 56, 56, 2)    38          lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 56, 56, 2)    38          lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 56, 56, 2)    38          lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 56, 56, 2)    38          lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 2)    38          lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 2)    38          lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 56, 56, 2)    38          lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 56, 56, 2)    38          lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 56, 56, 2)    38          lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 56, 56, 2)    38          lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 56, 56, 2)    38          lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 56, 56, 2)    38          lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 56, 56, 2)    38          lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 56, 56, 2)    38          lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 2)    38          lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 2)    38          lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 2)    38          lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 2)    38          lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 56, 56, 2)    38          lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 56, 56, 2)    38          lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 56, 56, 2)    38          lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 56, 56, 2)    38          lambda_63[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 64)   0           conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 64)   256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 56, 56, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 56, 56, 128)  8320        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 128)  512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 128)  0           leaky_re_lu_3[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 56, 56, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 56, 56, 64)   8256        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 64)   256         conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 56, 56, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 56, 56, 2)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 56, 56, 2)    38          lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 56, 56, 2)    38          lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 56, 56, 2)    38          lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 56, 56, 2)    38          lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 56, 56, 2)    38          lambda_68[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 56, 56, 2)    38          lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 56, 56, 2)    38          lambda_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 56, 56, 2)    38          lambda_71[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 56, 56, 2)    38          lambda_72[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 56, 56, 2)    38          lambda_73[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 56, 56, 2)    38          lambda_74[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 56, 56, 2)    38          lambda_75[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 56, 56, 2)    38          lambda_76[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 56, 56, 2)    38          lambda_77[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 56, 56, 2)    38          lambda_78[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 56, 56, 2)    38          lambda_79[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 56, 56, 2)    38          lambda_80[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 56, 56, 2)    38          lambda_81[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 56, 56, 2)    38          lambda_82[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_490 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_491 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_492 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_493 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_494 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_495 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_496 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_497 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_498 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_499 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_500 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_501 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_502 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_503 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_504 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_505 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_506 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_507 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_508 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_509 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_510 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_511 (Lambda)             (None, 7, 7, 16)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 7, 7, 16)     2320        lambda_480[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 7, 7, 16)     2320        lambda_481[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, 7, 7, 16)     2320        lambda_482[0][0]
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, 7, 7, 16)     2320        lambda_483[0][0]
# __________________________________________________________________________________________________
# conv2d_520 (Conv2D)             (None, 7, 7, 16)     2320        lambda_484[0][0]
# __________________________________________________________________________________________________
# conv2d_521 (Conv2D)             (None, 7, 7, 16)     2320        lambda_485[0][0]
# __________________________________________________________________________________________________
# conv2d_522 (Conv2D)             (None, 7, 7, 16)     2320        lambda_486[0][0]
# __________________________________________________________________________________________________
# conv2d_523 (Conv2D)             (None, 7, 7, 16)     2320        lambda_487[0][0]
# __________________________________________________________________________________________________
# conv2d_524 (Conv2D)             (None, 7, 7, 16)     2320        lambda_488[0][0]
# __________________________________________________________________________________________________
# conv2d_525 (Conv2D)             (None, 7, 7, 16)     2320        lambda_489[0][0]
# __________________________________________________________________________________________________
# conv2d_526 (Conv2D)             (None, 7, 7, 16)     2320        lambda_490[0][0]
# __________________________________________________________________________________________________
# conv2d_527 (Conv2D)             (None, 7, 7, 16)     2320        lambda_491[0][0]
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, 7, 7, 16)     2320        lambda_492[0][0]
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, 7, 7, 16)     2320        lambda_493[0][0]
# __________________________________________________________________________________________________
# conv2d_530 (Conv2D)             (None, 7, 7, 16)     2320        lambda_494[0][0]
# __________________________________________________________________________________________________
# conv2d_531 (Conv2D)             (None, 7, 7, 16)     2320        lambda_495[0][0]
# __________________________________________________________________________________________________
# conv2d_532 (Conv2D)             (None, 7, 7, 16)     2320        lambda_496[0][0]
# __________________________________________________________________________________________________
# conv2d_533 (Conv2D)             (None, 7, 7, 16)     2320        lambda_497[0][0]
# __________________________________________________________________________________________________
# conv2d_534 (Conv2D)             (None, 7, 7, 16)     2320        lambda_498[0][0]
# __________________________________________________________________________________________________
# conv2d_535 (Conv2D)             (None, 7, 7, 16)     2320        lambda_499[0][0]
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, 7, 7, 16)     2320        lambda_500[0][0]
# __________________________________________________________________________________________________
# conv2d_537 (Conv2D)             (None, 7, 7, 16)     2320        lambda_501[0][0]
# __________________________________________________________________________________________________
# conv2d_538 (Conv2D)             (None, 7, 7, 16)     2320        lambda_502[0][0]
# __________________________________________________________________________________________________
# conv2d_539 (Conv2D)             (None, 7, 7, 16)     2320        lambda_503[0][0]
# __________________________________________________________________________________________________
# conv2d_540 (Conv2D)             (None, 7, 7, 16)     2320        lambda_504[0][0]
# __________________________________________________________________________________________________
# conv2d_541 (Conv2D)             (None, 7, 7, 16)     2320        lambda_505[0][0]
# __________________________________________________________________________________________________
# conv2d_542 (Conv2D)             (None, 7, 7, 16)     2320        lambda_506[0][0]
# __________________________________________________________________________________________________
# conv2d_543 (Conv2D)             (None, 7, 7, 16)     2320        lambda_507[0][0]
# __________________________________________________________________________________________________
# conv2d_544 (Conv2D)             (None, 7, 7, 16)     2320        lambda_508[0][0]
# __________________________________________________________________________________________________
# conv2d_545 (Conv2D)             (None, 7, 7, 16)     2320        lambda_509[0][0]
# __________________________________________________________________________________________________
# conv2d_546 (Conv2D)             (None, 7, 7, 16)     2320        lambda_510[0][0]
# __________________________________________________________________________________________________
# conv2d_547 (Conv2D)             (None, 7, 7, 16)     2320        lambda_511[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 7, 7, 512)    0           conv2d_516[0][0]
#                                                                  conv2d_517[0][0]
#                                                                  conv2d_518[0][0]
#                                                                  conv2d_519[0][0]
#                                                                  conv2d_520[0][0]
#                                                                  conv2d_521[0][0]
#                                                                  conv2d_522[0][0]
#                                                                  conv2d_523[0][0]
#                                                                  conv2d_524[0][0]
#                                                                  conv2d_525[0][0]
#                                                                  conv2d_526[0][0]
#                                                                  conv2d_527[0][0]
#                                                                  conv2d_528[0][0]
#                                                                  conv2d_529[0][0]
#                                                                  conv2d_530[0][0]
#                                                                  conv2d_531[0][0]
#                                                                  conv2d_532[0][0]
#                                                                  conv2d_533[0][0]
#                                                                  conv2d_534[0][0]
#                                                                  conv2d_535[0][0]
#                                                                  conv2d_536[0][0]
#                                                                  conv2d_537[0][0]
#                                                                  conv2d_538[0][0]
#                                                                  conv2d_539[0][0]
#                                                                  conv2d_540[0][0]
#                                                                  conv2d_541[0][0]
#                                                                  conv2d_542[0][0]
#                                                                  conv2d_543[0][0]
#                                                                  conv2d_544[0][0]
#                                                                  conv2d_545[0][0]
#                                                                  conv2d_546[0][0]
#                                                                  conv2d_547[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 512)    2048        concatenate_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 7, 7, 512)    0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_548 (Conv2D)             (None, 7, 7, 2048)   1050624     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 2048)   8192        conv2d_548[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           leaky_re_lu_45[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 5)            10245       global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 9,050,629
# Trainable params: 9,007,877
# Non-trainable params: 42,752
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,classification_report 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import Normalizer

# %%
conf_matrix_list_of_arrays = []
#loss_per_fold = []
seed = 13   # for reproducibility you can change it. 
np.random.seed(seed)
roundlabel=[]
test=[]
idtest=[]
x_validate=[]
kfold = KFold(5, True, seed)
for train_idx, val_idx in kfold.split(np_train_image_list, y=bin_train_image_labels):
    #print('train: %s, val: %s' % (train_idx, val_idx))
    x_train, x_val = np_train_image_list[train_idx], np_train_image_list[val_idx]
    y_train, y_val= bin_train_image_labels[train_idx], bin_train_image_labels[val_idx]
    history=model.fit(x_train, y_train,
                  validation_data=(x_val, y_val),
                  batch_size=BS,
                  epochs=EPOCHS, verbose=1        
                  )
    ycalculated = model.predict(x_val)
    yhat_classes =np.argmax(ycalculated,axis=1)
    rounded_labels=np.argmax(y_val,axis=1)                           
    conf_matrix = confusion_matrix(rounded_labels,yhat_classes)
    conf_matrix_list_of_arrays .append(conf_matrix)
    roundlabel.append(rounded_labels)
    test.append(yhat_classes)
    idtest.append(val_idx)
    
print('Score per fold')
for i in range(0, len(conf_matrix_list_of_arrays)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1}  - Accuracy: {conf_matrix_list_of_arrays[i]}%')
# Out:
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/20
# 24000/24000 [==============================] - 386s 16ms/sample - loss: 1.5991 - accuracy: 0.3825 - val_loss: 1.8946 - val_accuracy: 0.3413
# Epoch 2/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 1.2049 - accuracy: 0.4959 - val_loss: 1.3763 - val_accuracy: 0.4927
# Epoch 3/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 1.0907 - accuracy: 0.5565 - val_loss: 1.1853 - val_accuracy: 0.4942
# Epoch 4/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 1.0059 - accuracy: 0.5954 - val_loss: 1.4876 - val_accuracy: 0.4223
# Epoch 5/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.9525 - accuracy: 0.6215 - val_loss: 1.2648 - val_accuracy: 0.5342
# Epoch 6/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 0.9064 - accuracy: 0.6412 - val_loss: 1.2867 - val_accuracy: 0.5238
# Epoch 7/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.8684 - accuracy: 0.6574 - val_loss: 1.1850 - val_accuracy: 0.5565
# Epoch 8/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.8306 - accuracy: 0.6771 - val_loss: 1.4977 - val_accuracy: 0.4943
# Epoch 9/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.7860 - accuracy: 0.6937 - val_loss: 1.0049 - val_accuracy: 0.6117
# Epoch 10/20
# 24000/24000 [==============================] - 339s 14ms/sample - loss: 0.7388 - accuracy: 0.7138 - val_loss: 0.9120 - val_accuracy: 0.6467
# Epoch 11/20
# 24000/24000 [==============================] - 339s 14ms/sample - loss: 0.6910 - accuracy: 0.7315 - val_loss: 1.1094 - val_accuracy: 0.6150
# Epoch 12/20
# 24000/24000 [==============================] - 339s 14ms/sample - loss: 0.6398 - accuracy: 0.7545 - val_loss: 1.0883 - val_accuracy: 0.5993
# Epoch 13/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.5859 - accuracy: 0.7785 - val_loss: 1.3142 - val_accuracy: 0.5490
# Epoch 14/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 0.5177 - accuracy: 0.8054 - val_loss: 1.1943 - val_accuracy: 0.6267
# Epoch 15/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 0.4464 - accuracy: 0.8318 - val_loss: 0.9352 - val_accuracy: 0.6953
# Epoch 16/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.3768 - accuracy: 0.8593 - val_loss: 0.9852 - val_accuracy: 0.6830
# Epoch 17/20
# 24000/24000 [==============================] - 336s 14ms/sample - loss: 0.3118 - accuracy: 0.8867 - val_loss: 1.0233 - val_accuracy: 0.7155
# Epoch 18/20
# 24000/24000 [==============================] - 336s 14ms/sample - loss: 0.2443 - accuracy: 0.9116 - val_loss: 1.2672 - val_accuracy: 0.6732
# Epoch 19/20
# 24000/24000 [==============================] - 336s 14ms/sample - loss: 0.2036 - accuracy: 0.9252 - val_loss: 1.5861 - val_accuracy: 0.6428
# Epoch 20/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.1604 - accuracy: 0.9423 - val_loss: 1.8282 - val_accuracy: 0.6042
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.3797 - accuracy: 0.8809 - val_loss: 0.1892 - val_accuracy: 0.9418
# Epoch 2/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.2452 - accuracy: 0.9207 - val_loss: 0.4702 - val_accuracy: 0.8332
# Epoch 3/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.1866 - accuracy: 0.9372 - val_loss: 0.2411 - val_accuracy: 0.9085
# Epoch 4/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.1377 - accuracy: 0.9522 - val_loss: 0.4042 - val_accuracy: 0.8543
# Epoch 5/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.1098 - accuracy: 0.9620 - val_loss: 0.2045 - val_accuracy: 0.9235
# Epoch 6/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0901 - accuracy: 0.9676 - val_loss: 0.2569 - val_accuracy: 0.9123
# Epoch 7/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0770 - accuracy: 0.9730 - val_loss: 0.2134 - val_accuracy: 0.9258
# Epoch 8/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0837 - accuracy: 0.9685 - val_loss: 0.3700 - val_accuracy: 0.8818
# Epoch 9/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0588 - accuracy: 0.9801 - val_loss: 0.4332 - val_accuracy: 0.8690
# Epoch 10/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0566 - accuracy: 0.9805 - val_loss: 0.7547 - val_accuracy: 0.8200
# Epoch 11/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0567 - accuracy: 0.9803 - val_loss: 0.4446 - val_accuracy: 0.8728
# Epoch 12/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0486 - accuracy: 0.9834 - val_loss: 0.4569 - val_accuracy: 0.8725
# Epoch 13/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0481 - accuracy: 0.9833 - val_loss: 0.4531 - val_accuracy: 0.8713
# Epoch 14/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0477 - accuracy: 0.9830 - val_loss: 0.3103 - val_accuracy: 0.8957
# Epoch 15/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 0.0320 - accuracy: 0.9895 - val_loss: 0.5515 - val_accuracy: 0.8605
# Epoch 16/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0435 - accuracy: 0.9851 - val_loss: 0.8280 - val_accuracy: 0.8148
# Epoch 17/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0326 - accuracy: 0.9890 - val_loss: 0.5053 - val_accuracy: 0.8735
# Epoch 18/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0432 - accuracy: 0.9847 - val_loss: 0.4771 - val_accuracy: 0.8853
# Epoch 19/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0316 - accuracy: 0.9891 - val_loss: 0.4078 - val_accuracy: 0.8862
# Epoch 20/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0226 - accuracy: 0.9919 - val_loss: 0.4771 - val_accuracy: 0.8813
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.1385 - accuracy: 0.9549 - val_loss: 0.1188 - val_accuracy: 0.9622
# Epoch 2/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0432 - accuracy: 0.9854 - val_loss: 0.1006 - val_accuracy: 0.9645
# Epoch 3/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0309 - accuracy: 0.9900 - val_loss: 0.0328 - val_accuracy: 0.9907
# Epoch 4/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0321 - accuracy: 0.9885 - val_loss: 0.1086 - val_accuracy: 0.9668
# Epoch 5/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0348 - accuracy: 0.9882 - val_loss: 0.1456 - val_accuracy: 0.9492
# Epoch 6/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.0200 - val_accuracy: 0.9942
# Epoch 7/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.0227 - accuracy: 0.9931 - val_loss: 0.0440 - val_accuracy: 0.9840
# Epoch 8/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0257 - accuracy: 0.9911 - val_loss: 0.0625 - val_accuracy: 0.9772
# Epoch 9/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0250 - accuracy: 0.9910 - val_loss: 0.1279 - val_accuracy: 0.9570
# Epoch 10/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0258 - accuracy: 0.9912 - val_loss: 0.0681 - val_accuracy: 0.9752
# Epoch 11/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.0238 - accuracy: 0.9917 - val_loss: 0.2062 - val_accuracy: 0.9348
# Epoch 12/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.0560 - val_accuracy: 0.9800
# Epoch 13/20
# 24000/24000 [==============================] - 338s 14ms/sample - loss: 0.0215 - accuracy: 0.9925 - val_loss: 0.0378 - val_accuracy: 0.9867
# Epoch 14/20
# 24000/24000 [==============================] - 339s 14ms/sample - loss: 0.0152 - accuracy: 0.9952 - val_loss: 0.0754 - val_accuracy: 0.9767
# Epoch 15/20
# 24000/24000 [==============================] - 339s 14ms/sample - loss: 0.0157 - accuracy: 0.9951 - val_loss: 0.0861 - val_accuracy: 0.9758
# Epoch 16/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.0755 - val_accuracy: 0.9732
# Epoch 17/20
# 24000/24000 [==============================] - 341s 14ms/sample - loss: 0.0167 - accuracy: 0.9947 - val_loss: 0.0704 - val_accuracy: 0.9762
# Epoch 18/20
# 24000/24000 [==============================] - 341s 14ms/sample - loss: 0.0171 - accuracy: 0.9943 - val_loss: 0.1061 - val_accuracy: 0.9637
# Epoch 19/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0406 - val_accuracy: 0.9845
# Epoch 20/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.0137 - accuracy: 0.9953 - val_loss: 0.0413 - val_accuracy: 0.9853
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/20
# 24000/24000 [==============================] - 340s 14ms/sample - loss: 0.0352 - accuracy: 0.9877 - val_loss: 0.0139 - val_accuracy: 0.9952
# Epoch 2/20
# 24000/24000 [==============================] - 342s 14ms/sample - loss: 0.0184 - accuracy: 0.9940 - val_loss: 0.0080 - val_accuracy: 0.9977
# Epoch 3/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.0057 - val_accuracy: 0.9980
# Epoch 4/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.0146 - accuracy: 0.9950 - val_loss: 0.0040 - val_accuracy: 0.9988
# Epoch 5/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0138 - val_accuracy: 0.9952
# Epoch 6/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0142 - accuracy: 0.9950 - val_loss: 0.0114 - val_accuracy: 0.9955
# Epoch 7/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0130 - accuracy: 0.9956 - val_loss: 0.1123 - val_accuracy: 0.9678
# Epoch 8/20
# 24000/24000 [==============================] - 339s 14ms/sample - loss: 0.0125 - accuracy: 0.9957 - val_loss: 0.0811 - val_accuracy: 0.9712
# Epoch 9/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0140 - val_accuracy: 0.9940
# Epoch 10/20
# 24000/24000 [==============================] - 334s 14ms/sample - loss: 0.0095 - accuracy: 0.9968 - val_loss: 0.0098 - val_accuracy: 0.9962
# Epoch 11/20
# 24000/24000 [==============================] - 335s 14ms/sample - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0348 - val_accuracy: 0.9895
# Epoch 12/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0395 - val_accuracy: 0.9850
# Epoch 13/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0200 - val_accuracy: 0.9932
# Epoch 14/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.1236 - val_accuracy: 0.9630
# Epoch 15/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0174 - val_accuracy: 0.9942
# Epoch 16/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0171 - val_accuracy: 0.9938
# Epoch 17/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0103 - accuracy: 0.9964 - val_loss: 0.0578 - val_accuracy: 0.9800
# Epoch 18/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0108 - val_accuracy: 0.9958
# Epoch 19/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0261 - val_accuracy: 0.9912
# Epoch 20/20
# 24000/24000 [==============================] - 328s 14ms/sample - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0710 - val_accuracy: 0.9748
# Train on 24000 samples, validate on 6000 samples
# Epoch 1/20
# 24000/24000 [==============================] - 333s 14ms/sample - loss: 0.0156 - accuracy: 0.9944 - val_loss: 0.0049 - val_accuracy: 0.9982
# Epoch 2/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0067 - val_accuracy: 0.9982
# Epoch 3/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0090 - val_accuracy: 0.9975
# Epoch 4/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0081 - accuracy: 0.9973 - val_loss: 0.0129 - val_accuracy: 0.9953
# Epoch 5/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0033 - val_accuracy: 0.9990
# Epoch 6/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0011 - val_accuracy: 0.9998
# Epoch 7/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0062 - accuracy: 0.9979 - val_loss: 0.0503 - val_accuracy: 0.9847
# Epoch 8/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.0818 - val_accuracy: 0.9755
# Epoch 9/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0602 - val_accuracy: 0.9817
# Epoch 10/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0109 - val_accuracy: 0.9965
# Epoch 11/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0044 - accuracy: 0.9984 - val_loss: 0.1766 - val_accuracy: 0.9510
# Epoch 12/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0101 - val_accuracy: 0.9970
# Epoch 13/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0138 - val_accuracy: 0.9947
# Epoch 14/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0058 - val_accuracy: 0.9977
# Epoch 15/20
# 24000/24000 [==============================] - 331s 14ms/sample - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0064 - val_accuracy: 0.9978
# Epoch 16/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0032 - val_accuracy: 0.9992
# Epoch 17/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0062 - accuracy: 0.9981 - val_loss: 0.0915 - val_accuracy: 0.9702
# Epoch 18/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0034 - val_accuracy: 0.9992
# Epoch 19/20
# 24000/24000 [==============================] - 330s 14ms/sample - loss: 0.0050 - accuracy: 0.9980 - val_loss: 0.0078 - val_accuracy: 0.9968
# Epoch 20/20
# 24000/24000 [==============================] - 332s 14ms/sample - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0164 - val_accuracy: 0.9945
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1  - Accuracy: [[820  64  52   1 266]
#  [130 649 249   2 195]
#  [ 27  37 813   2 318]
#  [ 20  67 397 487 185]
#  [157  58 142   6 856]]%
# ------------------------------------------------------------------------
# > Fold 2  - Accuracy: [[1146   15    6    1   42]
#  [ 109 1042   20    3   32]
#  [  43   48  988    7   94]
#  [   5   26   13 1190   20]
#  [ 139   29   52    8  922]]%
# ------------------------------------------------------------------------
# > Fold 3  - Accuracy: [[1187    4    5    1   12]
#  [   3 1149   11    6   12]
#  [   0    2 1195    1    7]
#  [   0    0    5 1166    1]
#  [   5    4    8    1 1215]]%
# ------------------------------------------------------------------------
# > Fold 4  - Accuracy: [[1235    2    0    0    2]
#  [  11 1165    0    0    5]
#  [  22   13 1119    2   63]
#  [   9    1    0 1171    8]
#  [   9    4    0    0 1159]]%
# ------------------------------------------------------------------------
# > Fold 5  - Accuracy: [[1135    0    0    0    4]
#  [   0 1188   16    1    2]
#  [   0    0 1191    0    8]
#  [   0    0    1 1227    1]
#  [   0    0    0    0 1226]]%

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'g', label='Training Accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation Accurarcy')
plt.title('Training and Validation Accurarcy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 'xx-large')

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
for i in range(5):
    plot_confusion_matrix(conf_matrix_list_of_arrays[i], 
                      normalize = False,
                      target_names = ['0', '1', '2','3','4'],
                      title        = "Confusion Matrix")

# %%
model.save('kaggle_test.h5')

# %%
print(tf.__version__)
# Out:
# 2.0.0

# %%
import streamlit

# %%
reconstructed_model = keras.models.load_model("keras_model.h5")

# %%
#from tensorflow.keras.preprocessing import image
from PIL import Image
from tensorflow.keras.applications import preprocess_input, decode_predictions
img_path = r'D:\kaggle\test_images\2216849948.jpg'
im = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = reconstructed_model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-0324502f7110> in <module>
#       1 #from tensorflow.keras.preprocessing import image
#       2 from PIL import Image
# ----> 3 from tensorflow.keras.applications import preprocess_input, decode_predictions
#       4 img_path = r'D:\kaggle\test_images\2216849948.jpg'
#       5 im = Image.open(img_path)
#
# ImportError: cannot import name 'preprocess_input' from 'tensorflow.keras.applications' (C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\tensorflow_core\python\keras\api\_v2\keras\applications\__init__.py)
