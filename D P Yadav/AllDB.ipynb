# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import numpy as np
import pickle
import cv2
from os import listdir
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('acc') >= 0.96):   
            print("Reached 95% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
import tensorflow as tf
import gc
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import VGG16, DenseNet169
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Activation, BatchNormalization, Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,TensorBoard,TerminateOnNaN, LearningRateScheduler
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
from tensorflow.keras.layers import Lambda, Reshape, DepthwiseConv2D, ZeroPadding2D, Add, MaxPooling2D,Activation, Flatten, Conv2D, Dense, Input, Dropout, Concatenate, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from imutils import paths
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os
#from classification_models.tfkeras import Classifiers
from datetime import datetime
# %load_ext tensorboard

# %%
EPOCHS =100
INIT_LR = 0.0001
BS =32
default_image_size = tuple((256, 256))
image_size = 0
width=256
height=256
depth=3
train_dir=r"D:\DP\AllDB"
#valid_dir=r"C:\Users\Glau\Desktop\DP\Pediastrum_cnn\Test"
train_folder=listdir(train_dir)
#valid_folder=listdir(valid_dir)

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
train_image_list, train_image_label=[],[]
for disease_folder in train_folder:
    print(f"processing {disease_folder} ...")
    disease_img_folder= listdir(f"{train_dir}/{disease_folder}")
    #print(disease_img_folder)
    for disease_img in disease_img_folder:
    #for disease_img in disease_img_folder[: : 2]:    
        image_directory = f"{train_dir}/{disease_folder}/{disease_img}"
        if image_directory.endswith(".jpeg") == True or image_directory.endswith(".jpg") == True or  image_directory.endswith(".png") == True:
            train_image_list.append(convert_image_to_array(image_directory))
            train_image_label.append(disease_folder)
print("[INFO] Image loading completed")
# Out:
# processing Blast ...
# processing Healthy ...
# [INFO] Image loading completed

# %%
label_binarizer = LabelBinarizer()
bin_train_image_labels = label_binarizer.fit_transform(train_image_label)
#bin_valid_image_labels = label_binarizer.fit_transform(valid_image_label)
pickle.dump(label_binarizer,open('Label_Instance_burn_labelBlast.pk', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
np_train_image_list = np.array(train_image_list, dtype=np.float32) / 255.0

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,classification_report 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import Normalizer

# %%
#Importing library
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np

np.random.seed(1000)

#Instantiation
AlexNet = Sequential()

#1st Convolutional Layer
AlexNet.add(Conv2D(filters=8, input_shape=(256,256,3), kernel_size=(5,5), strides=(4,4), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#2nd Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#3rd Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#4th Convolutional Layer
AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))

#5th Convolutional Layer
AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same'))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('relu'))
AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

#Passing it to a Fully Connected layer
AlexNet.add(Flatten())
# 1st Fully Connected Layer
#AlexNet.add(Dense(512, input_shape=(256,256,3,)))
#AlexNet.add(BatchNormalization())
#AlexNet.add(Activation('relu'))
# Add Dropout to prevent overfitting
#AlexNet.add(Dropout(0.4))

#2nd Fully Connected Layer
#AlexNet.add(Dense(4096))
#AlexNet.add(BatchNormalization())
#AlexNet.add(Activation('relu'))
#Add Dropout
#AlexNet.add(Dropout(0.4))

#3rd Fully Connected Layer
#AlexNet.add(Dense(10))
#AlexNet.add(BatchNormalization())
#AlexNet.add(Activation('relu'))
#Add Dropout
#AlexNet.add(Dropout(0.4))

#Output Layer
AlexNet.add(Dense(1))
AlexNet.add(BatchNormalization())
AlexNet.add(Activation('softmax'))

#Model Summary
AlexNet.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 64, 64, 8)         608
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 64, 64, 8)         32
# _________________________________________________________________
# activation_8 (Activation)    (None, 64, 64, 8)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 32, 32, 8)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 256)       51456
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# activation_9 (Activation)    (None, 32, 32, 256)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 384)       885120
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 16, 384)       1536
# _________________________________________________________________
# activation_10 (Activation)   (None, 16, 16, 384)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 384)       1327488
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16, 16, 384)       1536
# _________________________________________________________________
# activation_11 (Activation)   (None, 16, 16, 384)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 256)       884992
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16, 16, 256)       1024
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 16, 256)       0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               8389120
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 512)               2048
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 513
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 1)                 4
# _________________________________________________________________
# activation_14 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 11,546,501
# Trainable params: 11,542,899
# Non-trainable params: 3,602
# _________________________________________________________________

# %%
# coding: utf8
from tensorflow.keras import layers
from tensorflow.keras import models


#
# image dimensions
#

img_height = 256
img_width = 256
img_channels = 3

#
# network params
#

cardinality = 32


def residual_network(x):
    """
    ResNeXt by default. For ResNet set `cardinality` = 1 above.
    
    """
    def add_common_layers(y):
        y = layers.BatchNormalization()(y)
        y = layers.LeakyReLU()(y)

        return y

    def grouped_convolution(y, nb_channels, _strides):
        # when `cardinality` == 1 this is just a standard convolution
        if cardinality == 1:
            return layers.Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
        
        assert not nb_channels % cardinality
        _d = nb_channels // cardinality

        # in a grouped convolution layer, input and output channels are divided into `cardinality` groups,
        # and convolutions are separately performed within each group
        groups = []
        for j in range(cardinality):
            group = layers.Lambda(lambda z: z[:, :, :, j * _d:j * _d + _d])(y)
            groups.append(layers.Conv2D(_d, kernel_size=(3, 3), strides=_strides, padding='same')(group))
            
        # the grouped convolutional layer concatenates them as the outputs of the layer
        y = layers.concatenate(groups)

        return y

    def residual_block(y, nb_channels_in, nb_channels_out, _strides=(1, 1), _project_shortcut=False):
        """
        Our network consists of a stack of residual blocks. These blocks have the same topology,
        and are subject to two simple rules:

        - If producing spatial maps of the same size, the blocks share the same hyper-parameters (width and filter sizes).
        - Each time the spatial map is down-sampled by a factor of 2, the width of the blocks is multiplied by a factor of 2.
        """
        shortcut = y

        # we modify the residual building block as a bottleneck design to make the network more economical
        y = layers.Conv2D(nb_channels_in, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        y = add_common_layers(y)

        # ResNeXt (identical to ResNet when `cardinality` == 1)
        y = grouped_convolution(y, nb_channels_in, _strides=_strides)
        y = add_common_layers(y)

        y = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        # batch normalization is employed after aggregating the transformations and before adding to the shortcut
        y = layers.BatchNormalization()(y)

        # identity shortcuts used directly when the input and output are of the same dimensions
        if _project_shortcut or _strides != (1, 1):
            # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
            # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
            shortcut = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        y = layers.add([shortcut, y])

        # relu is performed right after each batch normalization,
        # expect for the output of the block where relu is performed after the adding to the shortcut
        y = layers.LeakyReLU()(y)

        return y

    # conv1
    x = layers.Conv2D(32, kernel_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = add_common_layers(x)

    # conv2
    x = layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    for i in range(3):#3
        project_shortcut = True if i == 0 else False
        x = residual_block(x, 64, 64, _project_shortcut=project_shortcut)

    # conv3
    for i in range(4):#4
        # down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 128, 64, _strides=strides)

    # conv4
    for i in range(6):#6
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 64, 128, _strides=strides)

    # conv5
    for i in range(3):#3
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 128, 1024, _strides=strides)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(2,activation='softmax')(x)

    return x


image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
network_output = residual_network(image_tensor)
  
model = models.Model(inputs=[image_tensor], outputs=[network_output])
print(model.summary())
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_2200 (Conv2D)            (None, 128, 128, 32) 896         input_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_216 (BatchN (None, 128, 128, 32) 128         conv2d_2200[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_200 (LeakyReLU)     (None, 128, 128, 32) 0           batch_normalization_216[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 32)   0           leaky_re_lu_200[0][0]
# __________________________________________________________________________________________________
# conv2d_2201 (Conv2D)            (None, 64, 64, 64)   2112        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_217 (BatchN (None, 64, 64, 64)   256         conv2d_2201[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_201 (LeakyReLU)     (None, 64, 64, 64)   0           batch_normalization_217[0][0]
# __________________________________________________________________________________________________
# lambda_2048 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2049 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2050 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2051 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2052 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2053 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2054 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2055 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2056 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2057 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2058 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2059 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2060 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2061 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2062 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2063 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2064 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2065 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2066 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2067 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2068 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2069 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2070 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2071 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2072 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2073 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2074 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2075 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2076 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2077 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2078 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# lambda_2079 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_201[0][0]
# __________________________________________________________________________________________________
# conv2d_2202 (Conv2D)            (None, 64, 64, 2)    38          lambda_2048[0][0]
# __________________________________________________________________________________________________
# conv2d_2203 (Conv2D)            (None, 64, 64, 2)    38          lambda_2049[0][0]
# __________________________________________________________________________________________________
# conv2d_2204 (Conv2D)            (None, 64, 64, 2)    38          lambda_2050[0][0]
# __________________________________________________________________________________________________
# conv2d_2205 (Conv2D)            (None, 64, 64, 2)    38          lambda_2051[0][0]
# __________________________________________________________________________________________________
# conv2d_2206 (Conv2D)            (None, 64, 64, 2)    38          lambda_2052[0][0]
# __________________________________________________________________________________________________
# conv2d_2207 (Conv2D)            (None, 64, 64, 2)    38          lambda_2053[0][0]
# __________________________________________________________________________________________________
# conv2d_2208 (Conv2D)            (None, 64, 64, 2)    38          lambda_2054[0][0]
# __________________________________________________________________________________________________
# conv2d_2209 (Conv2D)            (None, 64, 64, 2)    38          lambda_2055[0][0]
# __________________________________________________________________________________________________
# conv2d_2210 (Conv2D)            (None, 64, 64, 2)    38          lambda_2056[0][0]
# __________________________________________________________________________________________________
# conv2d_2211 (Conv2D)            (None, 64, 64, 2)    38          lambda_2057[0][0]
# __________________________________________________________________________________________________
# conv2d_2212 (Conv2D)            (None, 64, 64, 2)    38          lambda_2058[0][0]
# __________________________________________________________________________________________________
# conv2d_2213 (Conv2D)            (None, 64, 64, 2)    38          lambda_2059[0][0]
# __________________________________________________________________________________________________
# conv2d_2214 (Conv2D)            (None, 64, 64, 2)    38          lambda_2060[0][0]
# __________________________________________________________________________________________________
# conv2d_2215 (Conv2D)            (None, 64, 64, 2)    38          lambda_2061[0][0]
# __________________________________________________________________________________________________
# conv2d_2216 (Conv2D)            (None, 64, 64, 2)    38          lambda_2062[0][0]
# __________________________________________________________________________________________________
# conv2d_2217 (Conv2D)            (None, 64, 64, 2)    38          lambda_2063[0][0]
# __________________________________________________________________________________________________
# conv2d_2218 (Conv2D)            (None, 64, 64, 2)    38          lambda_2064[0][0]
# __________________________________________________________________________________________________
# conv2d_2219 (Conv2D)            (None, 64, 64, 2)    38          lambda_2065[0][0]
# __________________________________________________________________________________________________
# conv2d_2220 (Conv2D)            (None, 64, 64, 2)    38          lambda_2066[0][0]
# __________________________________________________________________________________________________
# conv2d_2221 (Conv2D)            (None, 64, 64, 2)    38          lambda_2067[0][0]
# __________________________________________________________________________________________________
# conv2d_2222 (Conv2D)            (None, 64, 64, 2)    38          lambda_2068[0][0]
# __________________________________________________________________________________________________
# conv2d_2223 (Conv2D)            (None, 64, 64, 2)    38          lambda_2069[0][0]
# __________________________________________________________________________________________________
# conv2d_2224 (Conv2D)            (None, 64, 64, 2)    38          lambda_2070[0][0]
# __________________________________________________________________________________________________
# conv2d_2225 (Conv2D)            (None, 64, 64, 2)    38          lambda_2071[0][0]
# __________________________________________________________________________________________________
# conv2d_2226 (Conv2D)            (None, 64, 64, 2)    38          lambda_2072[0][0]
# __________________________________________________________________________________________________
# conv2d_2227 (Conv2D)            (None, 64, 64, 2)    38          lambda_2073[0][0]
# __________________________________________________________________________________________________
# conv2d_2228 (Conv2D)            (None, 64, 64, 2)    38          lambda_2074[0][0]
# __________________________________________________________________________________________________
# conv2d_2229 (Conv2D)            (None, 64, 64, 2)    38          lambda_2075[0][0]
# __________________________________________________________________________________________________
# conv2d_2230 (Conv2D)            (None, 64, 64, 2)    38          lambda_2076[0][0]
# __________________________________________________________________________________________________
# conv2d_2231 (Conv2D)            (None, 64, 64, 2)    38          lambda_2077[0][0]
# __________________________________________________________________________________________________
# conv2d_2232 (Conv2D)            (None, 64, 64, 2)    38          lambda_2078[0][0]
# __________________________________________________________________________________________________
# conv2d_2233 (Conv2D)            (None, 64, 64, 2)    38          lambda_2079[0][0]
# __________________________________________________________________________________________________
# concatenate_64 (Concatenate)    (None, 64, 64, 64)   0           conv2d_2202[0][0]
#                                                                  conv2d_2203[0][0]
#                                                                  conv2d_2204[0][0]
#                                                                  conv2d_2205[0][0]
#                                                                  conv2d_2206[0][0]
#                                                                  conv2d_2207[0][0]
#                                                                  conv2d_2208[0][0]
#                                                                  conv2d_2209[0][0]
#                                                                  conv2d_2210[0][0]
#                                                                  conv2d_2211[0][0]
#                                                                  conv2d_2212[0][0]
#                                                                  conv2d_2213[0][0]
#                                                                  conv2d_2214[0][0]
#                                                                  conv2d_2215[0][0]
#                                                                  conv2d_2216[0][0]
#                                                                  conv2d_2217[0][0]
#                                                                  conv2d_2218[0][0]
#                                                                  conv2d_2219[0][0]
#                                                                  conv2d_2220[0][0]
#                                                                  conv2d_2221[0][0]
#                                                                  conv2d_2222[0][0]
#                                                                  conv2d_2223[0][0]
#                                                                  conv2d_2224[0][0]
#                                                                  conv2d_2225[0][0]
#                                                                  conv2d_2226[0][0]
#                                                                  conv2d_2227[0][0]
#                                                                  conv2d_2228[0][0]
#                                                                  conv2d_2229[0][0]
#                                                                  conv2d_2230[0][0]
#                                                                  conv2d_2231[0][0]
#                                                                  conv2d_2232[0][0]
#                                                                  conv2d_2233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_218 (BatchN (None, 64, 64, 64)   256         concatenate_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_202 (LeakyReLU)     (None, 64, 64, 64)   0           batch_normalization_218[0][0]
# __________________________________________________________________________________________________
# conv2d_2235 (Conv2D)            (None, 64, 64, 64)   2112        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_2234 (Conv2D)            (None, 64, 64, 64)   4160        leaky_re_lu_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_220 (BatchN (None, 64, 64, 64)   256         conv2d_2235[0][0]
# __________________________________________________________________________________________________
# batch_normalization_219 (BatchN (None, 64, 64, 64)   256         conv2d_2234[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 64, 64, 64)   0           batch_normalization_220[0][0]
#                                                                  batch_normalization_219[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_203 (LeakyReLU)     (None, 64, 64, 64)   0           add_64[0][0]
# __________________________________________________________________________________________________
# conv2d_2236 (Conv2D)            (None, 64, 64, 64)   4160        leaky_re_lu_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_221 (BatchN (None, 64, 64, 64)   256         conv2d_2236[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_204 (LeakyReLU)     (None, 64, 64, 64)   0           batch_normalization_221[0][0]
# __________________________________________________________________________________________________
# lambda_2080 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2081 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2082 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2083 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2084 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2085 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2086 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2087 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2088 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2089 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2090 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2091 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2092 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2093 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2094 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2095 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2096 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2097 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2098 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2099 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2100 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2101 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2102 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2103 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2104 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2105 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2106 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2107 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2108 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2109 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2110 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# lambda_2111 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_204[0][0]
# __________________________________________________________________________________________________
# conv2d_2237 (Conv2D)            (None, 64, 64, 2)    38          lambda_2080[0][0]
# __________________________________________________________________________________________________
# conv2d_2238 (Conv2D)            (None, 64, 64, 2)    38          lambda_2081[0][0]
# __________________________________________________________________________________________________
# conv2d_2239 (Conv2D)            (None, 64, 64, 2)    38          lambda_2082[0][0]
# __________________________________________________________________________________________________
# conv2d_2240 (Conv2D)            (None, 64, 64, 2)    38          lambda_2083[0][0]
# __________________________________________________________________________________________________
# conv2d_2241 (Conv2D)            (None, 64, 64, 2)    38          lambda_2084[0][0]
# __________________________________________________________________________________________________
# conv2d_2242 (Conv2D)            (None, 64, 64, 2)    38          lambda_2085[0][0]
# __________________________________________________________________________________________________
# conv2d_2243 (Conv2D)            (None, 64, 64, 2)    38          lambda_2086[0][0]
# __________________________________________________________________________________________________
# conv2d_2244 (Conv2D)            (None, 64, 64, 2)    38          lambda_2087[0][0]
# __________________________________________________________________________________________________
# conv2d_2245 (Conv2D)            (None, 64, 64, 2)    38          lambda_2088[0][0]
# __________________________________________________________________________________________________
# conv2d_2246 (Conv2D)            (None, 64, 64, 2)    38          lambda_2089[0][0]
# __________________________________________________________________________________________________
# conv2d_2247 (Conv2D)            (None, 64, 64, 2)    38          lambda_2090[0][0]
# __________________________________________________________________________________________________
# conv2d_2248 (Conv2D)            (None, 64, 64, 2)    38          lambda_2091[0][0]
# __________________________________________________________________________________________________
# conv2d_2249 (Conv2D)            (None, 64, 64, 2)    38          lambda_2092[0][0]
# __________________________________________________________________________________________________
# conv2d_2250 (Conv2D)            (None, 64, 64, 2)    38          lambda_2093[0][0]
# __________________________________________________________________________________________________
# conv2d_2251 (Conv2D)            (None, 64, 64, 2)    38          lambda_2094[0][0]
# __________________________________________________________________________________________________
# conv2d_2252 (Conv2D)            (None, 64, 64, 2)    38          lambda_2095[0][0]
# __________________________________________________________________________________________________
# conv2d_2253 (Conv2D)            (None, 64, 64, 2)    38          lambda_2096[0][0]
# __________________________________________________________________________________________________
# conv2d_2254 (Conv2D)            (None, 64, 64, 2)    38          lambda_2097[0][0]
# __________________________________________________________________________________________________
# conv2d_2255 (Conv2D)            (None, 64, 64, 2)    38          lambda_2098[0][0]
# __________________________________________________________________________________________________
# conv2d_2256 (Conv2D)            (None, 64, 64, 2)    38          lambda_2099[0][0]
# __________________________________________________________________________________________________
# conv2d_2257 (Conv2D)            (None, 64, 64, 2)    38          lambda_2100[0][0]
# __________________________________________________________________________________________________
# conv2d_2258 (Conv2D)            (None, 64, 64, 2)    38          lambda_2101[0][0]
# __________________________________________________________________________________________________
# conv2d_2259 (Conv2D)            (None, 64, 64, 2)    38          lambda_2102[0][0]
# __________________________________________________________________________________________________
# conv2d_2260 (Conv2D)            (None, 64, 64, 2)    38          lambda_2103[0][0]
# __________________________________________________________________________________________________
# conv2d_2261 (Conv2D)            (None, 64, 64, 2)    38          lambda_2104[0][0]
# __________________________________________________________________________________________________
# conv2d_2262 (Conv2D)            (None, 64, 64, 2)    38          lambda_2105[0][0]
# __________________________________________________________________________________________________
# conv2d_2263 (Conv2D)            (None, 64, 64, 2)    38          lambda_2106[0][0]
# __________________________________________________________________________________________________
# conv2d_2264 (Conv2D)            (None, 64, 64, 2)    38          lambda_2107[0][0]
# __________________________________________________________________________________________________
# conv2d_2265 (Conv2D)            (None, 64, 64, 2)    38          lambda_2108[0][0]
# __________________________________________________________________________________________________
# conv2d_2266 (Conv2D)            (None, 64, 64, 2)    38          lambda_2109[0][0]
# __________________________________________________________________________________________________
# conv2d_2267 (Conv2D)            (None, 64, 64, 2)    38          lambda_2110[0][0]
# __________________________________________________________________________________________________
# conv2d_2268 (Conv2D)            (None, 64, 64, 2)    38          lambda_2111[0][0]
# __________________________________________________________________________________________________
# concatenate_65 (Concatenate)    (None, 64, 64, 64)   0           conv2d_2237[0][0]
#                                                                  conv2d_2238[0][0]
#                                                                  conv2d_2239[0][0]
#                                                                  conv2d_2240[0][0]
#                                                                  conv2d_2241[0][0]
#                                                                  conv2d_2242[0][0]
#                                                                  conv2d_2243[0][0]
#                                                                  conv2d_2244[0][0]
#                                                                  conv2d_2245[0][0]
#                                                                  conv2d_2246[0][0]
#                                                                  conv2d_2247[0][0]
#                                                                  conv2d_2248[0][0]
#                                                                  conv2d_2249[0][0]
#                                                                  conv2d_2250[0][0]
#                                                                  conv2d_2251[0][0]
#                                                                  conv2d_2252[0][0]
#                                                                  conv2d_2253[0][0]
#                                                                  conv2d_2254[0][0]
#                                                                  conv2d_2255[0][0]
#                                                                  conv2d_2256[0][0]
#                                                                  conv2d_2257[0][0]
#                                                                  conv2d_2258[0][0]
#                                                                  conv2d_2259[0][0]
#                                                                  conv2d_2260[0][0]
#                                                                  conv2d_2261[0][0]
#                                                                  conv2d_2262[0][0]
#                                                                  conv2d_2263[0][0]
#                                                                  conv2d_2264[0][0]
#                                                                  conv2d_2265[0][0]
#                                                                  conv2d_2266[0][0]
#                                                                  conv2d_2267[0][0]
#                                                                  conv2d_2268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_222 (BatchN (None, 64, 64, 64)   256         concatenate_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_205 (LeakyReLU)     (None, 64, 64, 64)   0           batch_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv2d_2269 (Conv2D)            (None, 64, 64, 64)   4160        leaky_re_lu_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_223 (BatchN (None, 64, 64, 64)   256         conv2d_2269[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 64, 64, 64)   0           leaky_re_lu_203[0][0]
#                                                                  batch_normalization_223[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_206 (LeakyReLU)     (None, 64, 64, 64)   0           add_65[0][0]
# __________________________________________________________________________________________________
# conv2d_2270 (Conv2D)            (None, 64, 64, 64)   4160        leaky_re_lu_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_224 (BatchN (None, 64, 64, 64)   256         conv2d_2270[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_207 (LeakyReLU)     (None, 64, 64, 64)   0           batch_normalization_224[0][0]
# __________________________________________________________________________________________________
# lambda_2112 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2113 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2114 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2115 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2116 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2117 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2118 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2119 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2120 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2121 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2122 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2123 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2124 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2125 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2126 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2127 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2128 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2129 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2130 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2131 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2132 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2133 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2134 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2135 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2136 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2137 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2138 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2139 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2140 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2141 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2142 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# lambda_2143 (Lambda)            (None, 64, 64, 2)    0           leaky_re_lu_207[0][0]
# __________________________________________________________________________________________________
# conv2d_2271 (Conv2D)            (None, 64, 64, 2)    38          lambda_2112[0][0]
# __________________________________________________________________________________________________
# conv2d_2272 (Conv2D)            (None, 64, 64, 2)    38          lambda_2113[0][0]
# __________________________________________________________________________________________________
# conv2d_2273 (Conv2D)            (None, 64, 64, 2)    38          lambda_2114[0][0]
# __________________________________________________________________________________________________
# conv2d_2274 (Conv2D)            (None, 64, 64, 2)    38          lambda_2115[0][0]
# __________________________________________________________________________________________________
# conv2d_2275 (Conv2D)            (None, 64, 64, 2)    38          lambda_2116[0][0]
# __________________________________________________________________________________________________
# conv2d_2276 (Conv2D)            (None, 64, 64, 2)    38          lambda_2117[0][0]
# __________________________________________________________________________________________________
# conv2d_2277 (Conv2D)            (None, 64, 64, 2)    38          lambda_2118[0][0]
# __________________________________________________________________________________________________
# conv2d_2278 (Conv2D)            (None, 64, 64, 2)    38          lambda_2119[0][0]
# __________________________________________________________________________________________________
# conv2d_2279 (Conv2D)            (None, 64, 64, 2)    38          lambda_2120[0][0]
# __________________________________________________________________________________________________
# conv2d_2280 (Conv2D)            (None, 64, 64, 2)    38          lambda_2121[0][0]
# __________________________________________________________________________________________________
# conv2d_2281 (Conv2D)            (None, 64, 64, 2)    38          lambda_2122[0][0]
# __________________________________________________________________________________________________
# conv2d_2282 (Conv2D)            (None, 64, 64, 2)    38          lambda_2123[0][0]
# __________________________________________________________________________________________________
# conv2d_2283 (Conv2D)            (None, 64, 64, 2)    38          lambda_2124[0][0]
# __________________________________________________________________________________________________
# conv2d_2284 (Conv2D)            (None, 64, 64, 2)    38          lambda_2125[0][0]
# __________________________________________________________________________________________________
# conv2d_2285 (Conv2D)            (None, 64, 64, 2)    38          lambda_2126[0][0]
# __________________________________________________________________________________________________
# conv2d_2286 (Conv2D)            (None, 64, 64, 2)    38          lambda_2127[0][0]
# __________________________________________________________________________________________________
# conv2d_2287 (Conv2D)            (None, 64, 64, 2)    38          lambda_2128[0][0]
# __________________________________________________________________________________________________
# conv2d_2288 (Conv2D)            (None, 64, 64, 2)    38          lambda_2129[0][0]
# __________________________________________________________________________________________________
# conv2d_2289 (Conv2D)            (None, 64, 64, 2)    38          lambda_2130[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_2538 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2539 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2540 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2541 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2542 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2543 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2544 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2545 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2546 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2547 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2548 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2549 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2550 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2551 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2552 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2553 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2554 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2555 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2556 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2557 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2558 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# lambda_2559 (Lambda)            (None, 8, 8, 4)      0           leaky_re_lu_246[0][0]
# __________________________________________________________________________________________________
# conv2d_2716 (Conv2D)            (None, 8, 8, 4)      148         lambda_2528[0][0]
# __________________________________________________________________________________________________
# conv2d_2717 (Conv2D)            (None, 8, 8, 4)      148         lambda_2529[0][0]
# __________________________________________________________________________________________________
# conv2d_2718 (Conv2D)            (None, 8, 8, 4)      148         lambda_2530[0][0]
# __________________________________________________________________________________________________
# conv2d_2719 (Conv2D)            (None, 8, 8, 4)      148         lambda_2531[0][0]
# __________________________________________________________________________________________________
# conv2d_2720 (Conv2D)            (None, 8, 8, 4)      148         lambda_2532[0][0]
# __________________________________________________________________________________________________
# conv2d_2721 (Conv2D)            (None, 8, 8, 4)      148         lambda_2533[0][0]
# __________________________________________________________________________________________________
# conv2d_2722 (Conv2D)            (None, 8, 8, 4)      148         lambda_2534[0][0]
# __________________________________________________________________________________________________
# conv2d_2723 (Conv2D)            (None, 8, 8, 4)      148         lambda_2535[0][0]
# __________________________________________________________________________________________________
# conv2d_2724 (Conv2D)            (None, 8, 8, 4)      148         lambda_2536[0][0]
# __________________________________________________________________________________________________
# conv2d_2725 (Conv2D)            (None, 8, 8, 4)      148         lambda_2537[0][0]
# __________________________________________________________________________________________________
# conv2d_2726 (Conv2D)            (None, 8, 8, 4)      148         lambda_2538[0][0]
# __________________________________________________________________________________________________
# conv2d_2727 (Conv2D)            (None, 8, 8, 4)      148         lambda_2539[0][0]
# __________________________________________________________________________________________________
# conv2d_2728 (Conv2D)            (None, 8, 8, 4)      148         lambda_2540[0][0]
# __________________________________________________________________________________________________
# conv2d_2729 (Conv2D)            (None, 8, 8, 4)      148         lambda_2541[0][0]
# __________________________________________________________________________________________________
# conv2d_2730 (Conv2D)            (None, 8, 8, 4)      148         lambda_2542[0][0]
# __________________________________________________________________________________________________
# conv2d_2731 (Conv2D)            (None, 8, 8, 4)      148         lambda_2543[0][0]
# __________________________________________________________________________________________________
# conv2d_2732 (Conv2D)            (None, 8, 8, 4)      148         lambda_2544[0][0]
# __________________________________________________________________________________________________
# conv2d_2733 (Conv2D)            (None, 8, 8, 4)      148         lambda_2545[0][0]
# __________________________________________________________________________________________________
# conv2d_2734 (Conv2D)            (None, 8, 8, 4)      148         lambda_2546[0][0]
# __________________________________________________________________________________________________
# conv2d_2735 (Conv2D)            (None, 8, 8, 4)      148         lambda_2547[0][0]
# __________________________________________________________________________________________________
# conv2d_2736 (Conv2D)            (None, 8, 8, 4)      148         lambda_2548[0][0]
# __________________________________________________________________________________________________
# conv2d_2737 (Conv2D)            (None, 8, 8, 4)      148         lambda_2549[0][0]
# __________________________________________________________________________________________________
# conv2d_2738 (Conv2D)            (None, 8, 8, 4)      148         lambda_2550[0][0]
# __________________________________________________________________________________________________
# conv2d_2739 (Conv2D)            (None, 8, 8, 4)      148         lambda_2551[0][0]
# __________________________________________________________________________________________________
# conv2d_2740 (Conv2D)            (None, 8, 8, 4)      148         lambda_2552[0][0]
# __________________________________________________________________________________________________
# conv2d_2741 (Conv2D)            (None, 8, 8, 4)      148         lambda_2553[0][0]
# __________________________________________________________________________________________________
# conv2d_2742 (Conv2D)            (None, 8, 8, 4)      148         lambda_2554[0][0]
# __________________________________________________________________________________________________
# conv2d_2743 (Conv2D)            (None, 8, 8, 4)      148         lambda_2555[0][0]
# __________________________________________________________________________________________________
# conv2d_2744 (Conv2D)            (None, 8, 8, 4)      148         lambda_2556[0][0]
# __________________________________________________________________________________________________
# conv2d_2745 (Conv2D)            (None, 8, 8, 4)      148         lambda_2557[0][0]
# __________________________________________________________________________________________________
# conv2d_2746 (Conv2D)            (None, 8, 8, 4)      148         lambda_2558[0][0]
# __________________________________________________________________________________________________
# conv2d_2747 (Conv2D)            (None, 8, 8, 4)      148         lambda_2559[0][0]
# __________________________________________________________________________________________________
# concatenate_79 (Concatenate)    (None, 8, 8, 128)    0           conv2d_2716[0][0]
#                                                                  conv2d_2717[0][0]
#                                                                  conv2d_2718[0][0]
#                                                                  conv2d_2719[0][0]
#                                                                  conv2d_2720[0][0]
#                                                                  conv2d_2721[0][0]
#                                                                  conv2d_2722[0][0]
#                                                                  conv2d_2723[0][0]
#                                                                  conv2d_2724[0][0]
#                                                                  conv2d_2725[0][0]
#                                                                  conv2d_2726[0][0]
#                                                                  conv2d_2727[0][0]
#                                                                  conv2d_2728[0][0]
#                                                                  conv2d_2729[0][0]
#                                                                  conv2d_2730[0][0]
#                                                                  conv2d_2731[0][0]
#                                                                  conv2d_2732[0][0]
#                                                                  conv2d_2733[0][0]
#                                                                  conv2d_2734[0][0]
#                                                                  conv2d_2735[0][0]
#                                                                  conv2d_2736[0][0]
#                                                                  conv2d_2737[0][0]
#                                                                  conv2d_2738[0][0]
#                                                                  conv2d_2739[0][0]
#                                                                  conv2d_2740[0][0]
#                                                                  conv2d_2741[0][0]
#                                                                  conv2d_2742[0][0]
#                                                                  conv2d_2743[0][0]
#                                                                  conv2d_2744[0][0]
#                                                                  conv2d_2745[0][0]
#                                                                  conv2d_2746[0][0]
#                                                                  conv2d_2747[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 8, 8, 128)    512         concatenate_79[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_247 (LeakyReLU)     (None, 8, 8, 128)    0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# conv2d_2748 (Conv2D)            (None, 8, 8, 1024)   132096      leaky_re_lu_247[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 8, 8, 1024)   4096        conv2d_2748[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, 8, 8, 1024)   0           leaky_re_lu_245[0][0]
#                                                                  batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_248 (LeakyReLU)     (None, 8, 8, 1024)   0           add_79[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 1024)         0           leaky_re_lu_248[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            2050        global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 1,087,682
# Trainable params: 1,070,594
# Non-trainable params: 17,088
# __________________________________________________________________________________________________
# None

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

print("[INFO] training network...")
# Out:
# [INFO] training network...

# %%
conf_matrix_list_of_arrays = []
#loss_per_fold = []
seed = 10   # for reproducibility you can change it. 
np.random.seed(seed)
roundlabel=[]
test=[]
idtest=[]
x_validate=[]
kfold = KFold(3, True, seed)
for train_idx, val_idx in kfold.split(np_train_image_list, y=bin_train_image_labels):
    #print('train: %s, val: %s' % (train_idx, val_idx))
    x_train, x_val = np_train_image_list[train_idx], np_train_image_list[val_idx]
    y_train, y_val= bin_train_image_labels[train_idx], bin_train_image_labels[val_idx]
    history=model.fit(x_train, y_train,
                  validation_data=(x_val, y_val),
                  batch_size=BS,
                  epochs=EPOCHS, verbose=1        
                  )
    ycalculated = model.predict(x_val)
    yhat_classes =np.argmax(ycalculated,axis=1)
    rounded_labels=np.argmax(y_val,axis=1)                           
    conf_matrix = confusion_matrix(rounded_labels,yhat_classes)
    conf_matrix_list_of_arrays .append(conf_matrix)
    roundlabel.append(rounded_labels)
    test.append(yhat_classes)
    idtest.append(val_idx)
    
print('Score per fold')
for i in range(0, len(conf_matrix_list_of_arrays)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1}  - Accuracy: {conf_matrix_list_of_arrays[i]}%')
# Out:
# Train on 72 samples, validate on 36 samples
# Epoch 1/100
# 72/72 [==============================] - 48s 671ms/sample - loss: 0.8596 - accuracy: 0.3056 - val_loss: 0.6956 - val_accuracy: 0.4167
# Epoch 2/100
# 72/72 [==============================] - 1s 19ms/sample - loss: 0.4726 - accuracy: 0.7778 - val_loss: 0.6910 - val_accuracy: 0.5833
# Epoch 3/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.3526 - accuracy: 0.8194 - val_loss: 0.6821 - val_accuracy: 0.5833
# Epoch 4/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.2914 - accuracy: 0.8889 - val_loss: 0.6792 - val_accuracy: 0.5833
# Epoch 5/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.1690 - accuracy: 0.9306 - val_loss: 0.6798 - val_accuracy: 0.5833
# Epoch 6/100
# 72/72 [==============================] - 1s 19ms/sample - loss: 0.1019 - accuracy: 0.9861 - val_loss: 0.6825 - val_accuracy: 0.5833
# Epoch 7/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0605 - accuracy: 1.0000 - val_loss: 0.6876 - val_accuracy: 0.5833
# Epoch 8/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0338 - accuracy: 1.0000 - val_loss: 0.6957 - val_accuracy: 0.5833
# Epoch 9/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.7067 - val_accuracy: 0.5833
# Epoch 10/100
# 72/72 [==============================] - 1s 17ms/sample - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.7201 - val_accuracy: 0.5833
# Epoch 11/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.7359 - val_accuracy: 0.5833
# Epoch 12/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.7564 - val_accuracy: 0.5833
# Epoch 13/100
# 72/72 [==============================] - 1s 17ms/sample - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.7789 - val_accuracy: 0.5833
# Epoch 14/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0678 - accuracy: 0.9722 - val_loss: 0.8025 - val_accuracy: 0.5833
# Epoch 15/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.8274 - val_accuracy: 0.5833
# Epoch 16/100
# 72/72 [==============================] - 1s 17ms/sample - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.8528 - val_accuracy: 0.5833
# Epoch 17/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.8781 - val_accuracy: 0.5833
# Epoch 18/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0703 - accuracy: 0.9583 - val_loss: 0.9018 - val_accuracy: 0.5833
# Epoch 19/100
# 72/72 [==============================] - 1s 19ms/sample - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.9249 - val_accuracy: 0.5833
# Epoch 20/100
# 72/72 [==============================] - 1s 17ms/sample - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.9530 - val_accuracy: 0.5833
# Epoch 21/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.1280 - accuracy: 0.9444 - val_loss: 0.9751 - val_accuracy: 0.5833
# Epoch 22/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0276 - accuracy: 0.9861 - val_loss: 0.9678 - val_accuracy: 0.5833
# Epoch 23/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0719 - accuracy: 0.9722 - val_loss: 0.9573 - val_accuracy: 0.5833
# Epoch 24/100
# 72/72 [==============================] - 1s 17ms/sample - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.9352 - val_accuracy: 0.5833
# Epoch 25/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0348 - accuracy: 0.9861 - val_loss: 0.9290 - val_accuracy: 0.5833
# Epoch 26/100
# 72/72 [==============================] - 1s 17ms/sample - loss: 0.0414 - accuracy: 0.9861 - val_loss: 0.9446 - val_accuracy: 0.5833
# Epoch 27/100
# 72/72 [==============================] - 1s 18ms/sample - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.9757 - val_accuracy: 0.5833
# Epoch 28/100
# 72/72 [==============================] - 1s 19ms/sample - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.0170 - val_accuracy: 0.5833
# Epoch 29/100
# 72/72 [==============================] - 1s 19ms/sample - loss: 0.0051 - accuracy: 1.0000 - val_loss: 1.0650 - val_accuracy: 0.5833
# Epoch 30/100
# 32/72 [============>.................] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000
