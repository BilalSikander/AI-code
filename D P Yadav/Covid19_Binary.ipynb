# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import numpy as np
import pickle
import cv2
from os import listdir
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('acc') >= 0.96):   
            print("Reached 95% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
EPOCHS =100
INIT_LR = 3e-3
BS = 32
default_image_size = tuple((256, 256))
image_size = 0
width=256
height=256
depth=3
train_dir=r"C:\Users\Glau\Desktop\Binary Covid\Train"
valid_dir=r"C:\Users\Glau\Desktop\Binary Covid\Test"
train_folder=listdir(train_dir)
valid_folder=listdir(valid_dir)

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
callbacks = MyCustomCallback()

# %%
train_image_list, train_image_label= [], []
for disease_folder in train_folder:
    print(f"processing {disease_folder} ...")
    disease_img_folder= listdir(f"{train_dir}/{disease_folder}")
    #print(disease_img_folder)
    for disease_img in disease_img_folder:
    #for disease_img in disease_img_folder[: : 2]:    
        image_directory = f"{train_dir}/{disease_folder}/{disease_img}"
        if image_directory.endswith(".jpg") == True or image_directory.endswith(".TIFF") == True:
            train_image_list.append(convert_image_to_array(image_directory))
            train_image_label.append(disease_folder)
print("[INFO] Image loading completed")
# Out:
# processing Covid ...
# processing No-Findings ...
# [INFO] Image loading completed

# %%
print(len(train_image_label))
# Out:
# 32000

# %%
valid_image_list, valid_image_label= [], []
for disease_folder in valid_folder:
    print(f"processing {disease_folder} ...")
    disease_img_folder= listdir(f"{valid_dir}/{disease_folder}")
    for disease_img in disease_img_folder:
    #for disease_img in disease_img_folder[: : 2]: 
        image_directory = f"{valid_dir}/{disease_folder}/{disease_img}"
        if image_directory.endswith(".jpg") == True or image_directory.endswith(".TIFF") == True:
            valid_image_list.append(convert_image_to_array(image_directory))
            valid_image_label.append(disease_folder)
print("[INFO] Image loading completed")
# Out:
# processing Covid ...
# processing No-Findings ...
# [INFO] Image loading completed

# %%
print(len(valid_image_label))
# Out:
# 8000

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
bin_train_image_labels = label_binarizer.fit_transform(train_image_label)
bin_valid_image_labels = label_binarizer.fit_transform(valid_image_label)
pickle.dump(label_binarizer,open('Label_Instance_covid_bin.pkl', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(n_classes)
# Out:
# 2

# %%
np_train_image_list = np.array(train_image_list, dtype=np.float32) / 255.0
np_valid_image_list = np.array(valid_image_list, dtype=np.float32) / 255.0

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

# %%
from tensorflow.keras import models

from tensorflow.keras import layers
from tensorflow.keras import models

from tensorflow.keras import layers
#
# image dimensions
#

img_height = 256
img_width = 256
img_channels = 3

#
# network params
#

cardinality = 32


def residual_network(x):
    """
    ResNeXt by default. For ResNet set `cardinality` = 1 above.
    
    """
    def add_common_layers(y):
        y = layers.BatchNormalization()(y)
        y = layers.LeakyReLU()(y)

        return y

    def grouped_convolution(y, nb_channels, _strides):
        # when `cardinality` == 1 this is just a standard convolution
        if cardinality == 1:
            return layers.Conv2D(nb_channels, kernel_size=(3, 3), strides=_strides, padding='same')(y)
        
        assert not nb_channels % cardinality
        _d = nb_channels // cardinality

        # in a grouped convolution layer, input and output channels are divided into `cardinality` groups,
        # and convolutions are separately performed within each group
        groups = []
        for j in range(cardinality):
            group = layers.Lambda(lambda z: z[:, :, :, j * _d:j * _d + _d])(y)
            groups.append(layers.Conv2D(_d, kernel_size=(3, 3), strides=_strides, padding='same')(group))
            
        # the grouped convolutional layer concatenates them as the outputs of the layer
        y = layers.concatenate(groups)

        return y

    def residual_block(y, nb_channels_in, nb_channels_out, _strides=(1, 1), _project_shortcut=False):
        """
        Our network consists of a stack of residual blocks. These blocks have the same topology,
        and are subject to two simple rules:

        - If producing spatial maps of the same size, the blocks share the same hyper-parameters (width and filter sizes).
        - Each time the spatial map is down-sampled by a factor of 2, the width of the blocks is multiplied by a factor of 2.
        """
        shortcut = y

        # we modify the residual building block as a bottleneck design to make the network more economical
        y = layers.Conv2D(nb_channels_in, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        y = add_common_layers(y)

        # ResNeXt (identical to ResNet when `cardinality` == 1)
        y = grouped_convolution(y, nb_channels_in, _strides=_strides)
        y = add_common_layers(y)

        y = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
        # batch normalization is employed after aggregating the transformations and before adding to the shortcut
        y = layers.BatchNormalization()(y)

        # identity shortcuts used directly when the input and output are of the same dimensions
        if _project_shortcut or _strides != (1, 1):
            # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions)
            # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
            shortcut = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)

        y = layers.add([shortcut, y])

        # relu is performed right after each batch normalization,
        # expect for the output of the block where relu is performed after the adding to the shortcut
        y = layers.ReLU()(y)

        return y

    # conv1
    x = layers.Conv2D(32, kernel_size=(3, 3), strides=(2, 2), padding='same')(x)
    x = add_common_layers(x)

    # conv2
    x = layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)
    for i in range(3):
        project_shortcut = True if i == 0 else False
        x = residual_block(x, 64, 128, _project_shortcut=project_shortcut)

    # conv3
    for i in range(4):
        # down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 128, 256, _strides=strides)

    # conv4
    for i in range(6):
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 256, 1024, _strides=strides)

    # conv5
    for i in range(3):
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 1024, 2048, _strides=strides)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(2,activation='softmax')(x)

    return x


image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
network_output = residual_network(image_tensor)
  
model = models.Model(inputs=[image_tensor], outputs=[network_output])
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 128, 128, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 128, 128, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   2112        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 2)    38          lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 2)    38          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 2)    38          lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 2)    38          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 2)    38          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 2)    38          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 2)    38          lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 2)    38          lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 2)    38          lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 2)    38          lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 2)    38          lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 2)    38          lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 2)    38          lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 2)    38          lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 2)    38          lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 2)    38          lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 2)    38          lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 2)    38          lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 2)    38          lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 2)    38          lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 2)    38          lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 2)    38          lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 2)    38          lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 2)    38          lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 2)    38          lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 2)    38          lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 2)    38          lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 2)    38          lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 2)    38          lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 2)    38          lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 2)    38          lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 2)    38          lambda_31[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 64)   0           conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 64)   256         concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 128)  4224        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 128)  8320        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 64, 64, 128)  512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 64, 64, 128)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 64)   8256        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 2)    38          lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 2)    38          lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 2)    38          lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 2)    38          lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 2)    38          lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 2)    38          lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 2)    38          lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 64, 64, 2)    38          lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 64, 64, 2)    38          lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 64, 64, 2)    38          lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 64, 64, 2)    38          lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 64, 64, 2)    38          lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 64, 2)    38          lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 64, 2)    38          lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 2)    38          lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 64, 64, 2)    38          lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 2)    38          lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 2)    38          lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 64, 64, 2)    38          lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 2)    38          lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 2)    38          lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 2)    38          lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 2)    38          lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 2)    38          lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 2)    38          lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 2)    38          lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 64, 2)    38          lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 64, 64, 2)    38          lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 64, 64, 2)    38          lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 64, 64, 2)    38          lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 64, 64, 2)    38          lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 64, 64, 2)    38          lambda_63[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 64)   0           conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 64, 64, 128)  8320        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 128)  512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 128)  0           re_lu[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 64, 64, 128)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 64, 64, 64)   8256        re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 64, 64, 2)    0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 64, 64, 2)    38          lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 64, 64, 2)    38          lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 64, 64, 2)    38          lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 64, 64, 2)    38          lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 64, 64, 2)    38          lambda_68[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 64, 64, 2)    38          lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 64, 64, 2)    38          lambda_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 64, 64, 2)    38          lambda_71[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 64, 64, 2)    38          lambda_72[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 64, 64, 2)    38          lambda_73[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 64, 64, 2)    38          lambda_74[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 64, 64, 2)    38          lambda_75[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 64, 64, 2)    38          lambda_76[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 64, 64, 2)    38          lambda_77[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 64, 64, 2)    38          lambda_78[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 64, 64, 2)    38          lambda_79[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 64, 64, 2)    38          lambda_80[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 64, 64, 2)    38          lambda_81[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 64, 64, 2)    38          lambda_82[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_490 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_491 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_492 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_493 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_494 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_495 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_496 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_497 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_498 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_499 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_500 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_501 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_502 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_503 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_504 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_505 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_506 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_507 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_508 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_509 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_510 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# lambda_511 (Lambda)             (None, 8, 8, 32)     0           leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 8, 8, 32)     9248        lambda_480[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 8, 8, 32)     9248        lambda_481[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, 8, 8, 32)     9248        lambda_482[0][0]
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, 8, 8, 32)     9248        lambda_483[0][0]
# __________________________________________________________________________________________________
# conv2d_520 (Conv2D)             (None, 8, 8, 32)     9248        lambda_484[0][0]
# __________________________________________________________________________________________________
# conv2d_521 (Conv2D)             (None, 8, 8, 32)     9248        lambda_485[0][0]
# __________________________________________________________________________________________________
# conv2d_522 (Conv2D)             (None, 8, 8, 32)     9248        lambda_486[0][0]
# __________________________________________________________________________________________________
# conv2d_523 (Conv2D)             (None, 8, 8, 32)     9248        lambda_487[0][0]
# __________________________________________________________________________________________________
# conv2d_524 (Conv2D)             (None, 8, 8, 32)     9248        lambda_488[0][0]
# __________________________________________________________________________________________________
# conv2d_525 (Conv2D)             (None, 8, 8, 32)     9248        lambda_489[0][0]
# __________________________________________________________________________________________________
# conv2d_526 (Conv2D)             (None, 8, 8, 32)     9248        lambda_490[0][0]
# __________________________________________________________________________________________________
# conv2d_527 (Conv2D)             (None, 8, 8, 32)     9248        lambda_491[0][0]
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, 8, 8, 32)     9248        lambda_492[0][0]
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, 8, 8, 32)     9248        lambda_493[0][0]
# __________________________________________________________________________________________________
# conv2d_530 (Conv2D)             (None, 8, 8, 32)     9248        lambda_494[0][0]
# __________________________________________________________________________________________________
# conv2d_531 (Conv2D)             (None, 8, 8, 32)     9248        lambda_495[0][0]
# __________________________________________________________________________________________________
# conv2d_532 (Conv2D)             (None, 8, 8, 32)     9248        lambda_496[0][0]
# __________________________________________________________________________________________________
# conv2d_533 (Conv2D)             (None, 8, 8, 32)     9248        lambda_497[0][0]
# __________________________________________________________________________________________________
# conv2d_534 (Conv2D)             (None, 8, 8, 32)     9248        lambda_498[0][0]
# __________________________________________________________________________________________________
# conv2d_535 (Conv2D)             (None, 8, 8, 32)     9248        lambda_499[0][0]
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, 8, 8, 32)     9248        lambda_500[0][0]
# __________________________________________________________________________________________________
# conv2d_537 (Conv2D)             (None, 8, 8, 32)     9248        lambda_501[0][0]
# __________________________________________________________________________________________________
# conv2d_538 (Conv2D)             (None, 8, 8, 32)     9248        lambda_502[0][0]
# __________________________________________________________________________________________________
# conv2d_539 (Conv2D)             (None, 8, 8, 32)     9248        lambda_503[0][0]
# __________________________________________________________________________________________________
# conv2d_540 (Conv2D)             (None, 8, 8, 32)     9248        lambda_504[0][0]
# __________________________________________________________________________________________________
# conv2d_541 (Conv2D)             (None, 8, 8, 32)     9248        lambda_505[0][0]
# __________________________________________________________________________________________________
# conv2d_542 (Conv2D)             (None, 8, 8, 32)     9248        lambda_506[0][0]
# __________________________________________________________________________________________________
# conv2d_543 (Conv2D)             (None, 8, 8, 32)     9248        lambda_507[0][0]
# __________________________________________________________________________________________________
# conv2d_544 (Conv2D)             (None, 8, 8, 32)     9248        lambda_508[0][0]
# __________________________________________________________________________________________________
# conv2d_545 (Conv2D)             (None, 8, 8, 32)     9248        lambda_509[0][0]
# __________________________________________________________________________________________________
# conv2d_546 (Conv2D)             (None, 8, 8, 32)     9248        lambda_510[0][0]
# __________________________________________________________________________________________________
# conv2d_547 (Conv2D)             (None, 8, 8, 32)     9248        lambda_511[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 8, 8, 1024)   0           conv2d_516[0][0]
#                                                                  conv2d_517[0][0]
#                                                                  conv2d_518[0][0]
#                                                                  conv2d_519[0][0]
#                                                                  conv2d_520[0][0]
#                                                                  conv2d_521[0][0]
#                                                                  conv2d_522[0][0]
#                                                                  conv2d_523[0][0]
#                                                                  conv2d_524[0][0]
#                                                                  conv2d_525[0][0]
#                                                                  conv2d_526[0][0]
#                                                                  conv2d_527[0][0]
#                                                                  conv2d_528[0][0]
#                                                                  conv2d_529[0][0]
#                                                                  conv2d_530[0][0]
#                                                                  conv2d_531[0][0]
#                                                                  conv2d_532[0][0]
#                                                                  conv2d_533[0][0]
#                                                                  conv2d_534[0][0]
#                                                                  conv2d_535[0][0]
#                                                                  conv2d_536[0][0]
#                                                                  conv2d_537[0][0]
#                                                                  conv2d_538[0][0]
#                                                                  conv2d_539[0][0]
#                                                                  conv2d_540[0][0]
#                                                                  conv2d_541[0][0]
#                                                                  conv2d_542[0][0]
#                                                                  conv2d_543[0][0]
#                                                                  conv2d_544[0][0]
#                                                                  conv2d_545[0][0]
#                                                                  conv2d_546[0][0]
#                                                                  conv2d_547[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8, 8, 1024)   4096        concatenate_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 8, 8, 1024)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_548 (Conv2D)             (None, 8, 8, 2048)   2099200     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8, 8, 2048)   8192        conv2d_548[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 2048)   0           re_lu_14[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# re_lu_15 (ReLU)                 (None, 8, 8, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           re_lu_15[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 2)            4098        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 18,329,602
# Trainable params: 18,273,986
# Non-trainable params: 55,616
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

print("[INFO] training network...")
# Out:
# [INFO] training network...

# %%
history=model.fit(np_train_image_list,bin_train_image_labels,
                  validation_data=(np_valid_image_list, bin_valid_image_labels),
                  batch_size=BS,
                  epochs=EPOCHS, verbose=1        
                  )
# Out:
# Train on 32000 samples, validate on 8000 samples
# Epoch 1/100
# 32000/32000 [==============================] - 502s 16ms/sample - loss: 0.1616 - accuracy: 0.9606 - val_loss: 0.2675 - val_accuracy: 0.9531
# Epoch 2/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0564 - accuracy: 0.9829 - val_loss: 2.0865 - val_accuracy: 0.7057
# Epoch 3/100
# 32000/32000 [==============================] - 466s 15ms/sample - loss: 0.0297 - accuracy: 0.9904 - val_loss: 1.6335 - val_accuracy: 0.8073
# Epoch 4/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0277 - accuracy: 0.9915 - val_loss: 0.0874 - val_accuracy: 0.9797
# Epoch 5/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0254 - accuracy: 0.9918 - val_loss: 2.3161 - val_accuracy: 0.6302
# Epoch 6/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0287 - accuracy: 0.9907 - val_loss: 0.1435 - val_accuracy: 0.9346
# Epoch 7/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0136 - accuracy: 0.9957 - val_loss: 0.0527 - val_accuracy: 0.9858
# Epoch 8/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 0.0173 - accuracy: 0.9942 - val_loss: 15.3595 - val_accuracy: 0.5000
# Epoch 9/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0176 - accuracy: 0.9942 - val_loss: 0.0086 - val_accuracy: 0.9979
# Epoch 10/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0151 - accuracy: 0.9952 - val_loss: 0.6284 - val_accuracy: 0.8917
# Epoch 11/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0085 - accuracy: 0.9973 - val_loss: 0.3219 - val_accuracy: 0.9514
# Epoch 12/100
# 32000/32000 [==============================] - 464s 14ms/sample - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.1214 - val_accuracy: 0.9596
# Epoch 13/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0122 - accuracy: 0.9961 - val_loss: 0.0164 - val_accuracy: 0.9946
# Epoch 14/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.2446 - val_accuracy: 0.9094
# Epoch 15/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 0.0072 - accuracy: 0.9975 - val_loss: 4.0815 - val_accuracy: 0.6865
# Epoch 16/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.5721 - val_accuracy: 0.8511
# Epoch 17/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.1470 - val_accuracy: 0.9486
# Epoch 18/100
# 32000/32000 [==============================] - 462s 14ms/sample - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.4597 - val_accuracy: 0.8637
# Epoch 19/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0015 - val_accuracy: 0.9998
# Epoch 20/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.4145 - val_accuracy: 0.9191
# Epoch 21/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.8436 - val_accuracy: 0.8850
# Epoch 22/100
# 32000/32000 [==============================] - 464s 15ms/sample - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.1210 - val_accuracy: 0.9674
# Epoch 23/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0018 - accuracy: 0.9994 - val_loss: 6.2898e-04 - val_accuracy: 0.9998
# Epoch 24/100
# 32000/32000 [==============================] - 462s 14ms/sample - loss: 1.6805e-04 - accuracy: 1.0000 - val_loss: 9.7473e-04 - val_accuracy: 0.9996
# Epoch 25/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0038 - accuracy: 0.9988 - val_loss: 0.1764 - val_accuracy: 0.9526
# Epoch 26/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0012 - val_accuracy: 0.9996
# Epoch 27/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0927 - val_accuracy: 0.9774
# Epoch 28/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 7.1277e-04 - accuracy: 0.9998 - val_loss: 0.0182 - val_accuracy: 0.9930
# Epoch 29/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 0.0116 - accuracy: 0.9982 - val_loss: 1.0568 - val_accuracy: 0.8788
# Epoch 30/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 31/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 4.9720e-04 - accuracy: 0.9999 - val_loss: 0.1317 - val_accuracy: 0.9824
# Epoch 32/100
# 32000/32000 [==============================] - 464s 14ms/sample - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0163 - val_accuracy: 0.9960
# Epoch 33/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 8.9938e-04 - accuracy: 0.9997 - val_loss: 0.0020 - val_accuracy: 0.9992
# Epoch 34/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 35/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 1.1483e-04 - accuracy: 1.0000 - val_loss: 4.9455e-04 - val_accuracy: 0.9999
# Epoch 36/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0029 - accuracy: 0.9991 - val_loss: 1.9896 - val_accuracy: 0.7230
# Epoch 37/100
# 32000/32000 [==============================] - 463s 14ms/sample - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0014 - val_accuracy: 0.9996
# Epoch 38/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0011 - accuracy: 0.9998 - val_loss: 1.7674 - val_accuracy: 0.7519
# Epoch 39/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 4.5618e-04 - accuracy: 0.9999 - val_loss: 0.0022 - val_accuracy: 0.9995
# Epoch 40/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 4.9188e-05 - accuracy: 1.0000 - val_loss: 2.2382e-04 - val_accuracy: 1.0000
# Epoch 41/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 2.0162e-05 - accuracy: 1.0000 - val_loss: 9.1323e-04 - val_accuracy: 0.9999
# Epoch 42/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 0.0027 - accuracy: 0.9990 - val_loss: 4.8282e-04 - val_accuracy: 0.9998
# Epoch 43/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 2.9429e-04 - accuracy: 0.9999 - val_loss: 5.6687e-04 - val_accuracy: 1.0000
# Epoch 44/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 0.0021 - accuracy: 0.9993 - val_loss: 6.1009e-04 - val_accuracy: 0.9999
# Epoch 45/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 8.7638e-05 - accuracy: 1.0000 - val_loss: 4.1441e-04 - val_accuracy: 0.9999
# Epoch 46/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0107 - val_accuracy: 0.9960
# Epoch 47/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 1.1459e-04 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 0.9984
# Epoch 48/100
# 32000/32000 [==============================] - 462s 14ms/sample - loss: 6.3141e-04 - accuracy: 0.9998 - val_loss: 6.5040e-04 - val_accuracy: 0.9998
# Epoch 49/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 4.1224e-04 - accuracy: 0.9998 - val_loss: 0.1934 - val_accuracy: 0.9606
# Epoch 50/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 9.2164e-04 - accuracy: 0.9996 - val_loss: 0.0836 - val_accuracy: 0.9815
# Epoch 51/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 7.7284e-05 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9764
# Epoch 52/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 9.8237e-04 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 0.9995
# Epoch 53/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 9.5518e-04 - accuracy: 0.9997 - val_loss: 0.0154 - val_accuracy: 0.9956
# Epoch 54/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 1.4609e-04 - accuracy: 0.9999 - val_loss: 0.0153 - val_accuracy: 0.9946
# Epoch 55/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 9.5872e-05 - accuracy: 1.0000 - val_loss: 2.5635e-04 - val_accuracy: 0.9999
# Epoch 56/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 6.6961e-06 - accuracy: 1.0000 - val_loss: 5.3654e-04 - val_accuracy: 0.9998
# Epoch 57/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1249 - val_accuracy: 0.9751
# Epoch 58/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 1.2050e-04 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9998
# Epoch 59/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0015 - val_accuracy: 0.9998
# Epoch 60/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 1.0552e-04 - accuracy: 1.0000 - val_loss: 2.6161e-04 - val_accuracy: 0.9999
# Epoch 61/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 1.7376e-05 - accuracy: 1.0000 - val_loss: 0.0431 - val_accuracy: 0.9858
# Epoch 62/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 0.0020 - accuracy: 0.9995 - val_loss: 3.1551e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 8.7828e-05 - accuracy: 0.9999 - val_loss: 1.5377e-04 - val_accuracy: 0.9999
# Epoch 64/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 1.1824e-04 - accuracy: 1.0000 - val_loss: 5.0258e-04 - val_accuracy: 0.9998
# Epoch 65/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 7.1829e-06 - accuracy: 1.0000 - val_loss: 4.9827e-04 - val_accuracy: 0.9998
# Epoch 66/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 6.4419e-06 - accuracy: 1.0000 - val_loss: 1.1874e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 2.2519e-06 - accuracy: 1.0000 - val_loss: 1.5786e-04 - val_accuracy: 0.9999
# Epoch 68/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 3.5499e-06 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 0.9991
# Epoch 69/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0018 - val_accuracy: 0.9995
# Epoch 70/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 1.2046e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 0.9996
# Epoch 71/100
# 32000/32000 [==============================] - 459s 14ms/sample - loss: 2.1661e-04 - accuracy: 0.9999 - val_loss: 0.0021 - val_accuracy: 0.9995
# Epoch 72/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 3.8885e-05 - accuracy: 1.0000 - val_loss: 1.1648e-04 - val_accuracy: 0.9999
# Epoch 73/100
# 32000/32000 [==============================] - 462s 14ms/sample - loss: 9.4401e-06 - accuracy: 1.0000 - val_loss: 9.8540e-04 - val_accuracy: 0.9996
# Epoch 74/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 7.7523e-06 - accuracy: 1.0000 - val_loss: 8.4997e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 3.8442e-06 - accuracy: 1.0000 - val_loss: 4.4626e-04 - val_accuracy: 0.9998
# Epoch 76/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 3.5443e-06 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 0.9975
# Epoch 77/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 5.3631e-04 - accuracy: 0.9998 - val_loss: 0.0734 - val_accuracy: 0.9904
# Epoch 78/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 4.8841e-04 - accuracy: 0.9998 - val_loss: 0.0139 - val_accuracy: 0.9971
# Epoch 79/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 1.1362e-04 - accuracy: 1.0000 - val_loss: 5.9165 - val_accuracy: 0.5527
# Epoch 80/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 2.3363e-04 - accuracy: 0.9999 - val_loss: 6.1620e-04 - val_accuracy: 0.9999
# Epoch 81/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 4.1447e-06 - accuracy: 1.0000 - val_loss: 5.4221e-04 - val_accuracy: 0.9999
# Epoch 82/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 5.2792e-06 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9970
# Epoch 83/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 6.5253e-06 - accuracy: 1.0000 - val_loss: 5.0543e-04 - val_accuracy: 0.9998
# Epoch 84/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 1.0306e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 0.9994
# Epoch 85/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0017 - val_accuracy: 0.9994
# Epoch 86/100
# 32000/32000 [==============================] - 458s 14ms/sample - loss: 1.7932e-05 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 0.9996
# Epoch 87/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 2.3336e-05 - accuracy: 1.0000 - val_loss: 6.2045e-04 - val_accuracy: 0.9998
# Epoch 88/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 2.7790e-06 - accuracy: 1.0000 - val_loss: 5.9453e-04 - val_accuracy: 0.9998
# Epoch 89/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 3.8945e-06 - accuracy: 1.0000 - val_loss: 5.7604e-04 - val_accuracy: 0.9998
# Epoch 90/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 9.4337e-06 - accuracy: 1.0000 - val_loss: 5.3132e-04 - val_accuracy: 0.9998
# Epoch 91/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 2.2723e-06 - accuracy: 1.0000 - val_loss: 5.4834e-04 - val_accuracy: 0.9998
# Epoch 92/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 5.0210e-04 - accuracy: 0.9998 - val_loss: 5.4389e-04 - val_accuracy: 0.9998
# Epoch 93/100
# 32000/32000 [==============================] - 455s 14ms/sample - loss: 2.2728e-04 - accuracy: 1.0000 - val_loss: 4.3278e-04 - val_accuracy: 0.9998
# Epoch 94/100
# 32000/32000 [==============================] - 460s 14ms/sample - loss: 3.5327e-05 - accuracy: 1.0000 - val_loss: 0.2082 - val_accuracy: 0.9592
# Epoch 95/100
# 32000/32000 [==============================] - 455s 14ms/sample - loss: 2.2535e-04 - accuracy: 0.9999 - val_loss: 2.7070e-04 - val_accuracy: 0.9998
# Epoch 96/100
# 32000/32000 [==============================] - 457s 14ms/sample - loss: 2.3313e-04 - accuracy: 0.9999 - val_loss: 0.2044 - val_accuracy: 0.9827
# Epoch 97/100
# 32000/32000 [==============================] - 461s 14ms/sample - loss: 5.9940e-05 - accuracy: 1.0000 - val_loss: 7.8796e-04 - val_accuracy: 0.9999
# Epoch 98/100
# 32000/32000 [==============================] - 455s 14ms/sample - loss: 4.4165e-06 - accuracy: 1.0000 - val_loss: 6.7816e-04 - val_accuracy: 0.9999
# Epoch 99/100
# 32000/32000 [==============================] - 455s 14ms/sample - loss: 8.3731e-07 - accuracy: 1.0000 - val_loss: 6.0905e-04 - val_accuracy: 0.9999
# Epoch 100/100
# 32000/32000 [==============================] - 456s 14ms/sample - loss: 7.5898e-07 - accuracy: 1.0000 - val_loss: 5.4738e-04 - val_accuracy: 0.9999

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(np_valid_image_list, bin_valid_image_labels)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 8000/8000 [==============================] - 27s 3ms/sample - loss: 5.4738e-04 - accuracy: 0.9999
# Test Accuracy: 99.9875009059906

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'g', label='Training Accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation Accurarcy')
plt.title('Training and Validation Accurarcy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
ycalculated = model.predict(np_valid_image_list)

# %%
yhat_classes =np.argmax(ycalculated,axis=1)

# %%
import numpy as np
rounded_labels=np.argmax(bin_valid_image_labels,axis=1)

# %%
from sklearn.metrics import accuracy_score,classification_report 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import Normalizer
#import seaborn as sns
#y_pred=model.predict_classes(np_valid_image_list)
#con_mat = tf.math.confusion_matrix(labels=y_true, predictions=ycalculated).numpy()
#matrix = confusion_matrix(rounded_labels,yhat_classes)
#y_pred=model.predict(np.array(val_image_list))
#yhat_classes = ["honda", "chevrolet", "honda", "toyota", "toyota", "chevrolet"]
#rounded_labels = ["honda", "chevrolet", "honda", "toyota", "toyota", "honda"]
cm =confusion_matrix(bin_valid_image_labels,yhat_classes)  

#matrix =confusion_matrix(bin_val_image_labels.argmax(axis=1), ycalculated)
#print(ma

# %%
re=recall_score(bin_valid_image_labels,yhat_classes,average='binary')
print(re)
# Out:
# 1.0

# %%
accuracy = accuracy_score(bin_valid_image_labels,yhat_classes) 
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.999875

# %%
import numpy as np

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 'xx-large')

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
plot_confusion_matrix(cm, 
                      normalize = False,
                      target_names = ['covid19','No-Findings'],
                      title        = "Confusion Matrix")

# %%
from sklearn.metrics import accuracy_score,classification_report 
target_names = ['Covid19', 'No-Findings'] 
print(classification_report(bin_valid_image_labels, yhat_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Covid19       1.00      1.00      1.00      4000
#  No-Findings       1.00      1.00      1.00      4000
#
#     accuracy                           1.00      8000
#    macro avg       1.00      1.00      1.00      8000
# weighted avg       1.00      1.00      1.00      8000

# %%
from sklearn.metrics import accuracy_score,classification_report 
target_names = ['Covid19','No-Findings']
print(classification_report(bin_valid_image_labels, yhat_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Covid19       1.00      1.00      1.00      4000
#  No-Findings       1.00      1.00      1.00      4000
#
#     accuracy                           1.00      8000
#    macro avg       1.00      1.00      1.00      8000
# weighted avg       1.00      1.00      1.00      8000

# %%
fpr, tpr, threshold = roc_curve(bin_valid_image_labels,yhat_classes) 

plt.plot(fpr, tpr, 'b')
plt.plot([0,1],[0,1], 'r--')
plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)

plt.show()

# %%
from sklearn.metrics import roc_curve, auc
fpr, tpr, thresholds = roc_curve(y_val,yhat_classes)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, color='b', lw=1, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='red', lw=lw, linestyle='--')
#plt.xlim([0.0, 1.0])
#plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-155b64987812> in <module>
#       1 from sklearn.metrics import roc_curve, auc
# ----> 2 fpr, tpr, thresholds = roc_curve(y_val,yhat_classes)
#       3 roc_auc = auc(fpr, tpr)
#       4
#       5 plt.figure()
#
# NameError: name 'y_val' is not defined

# %%
# compute the confusion matrix and and use it to derive the raw
# accuracy, sensitivity, and specificity
#cm = confusion_matrix(testY, np.argmax(predY, axis = -1))
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)

print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [[3999    1]
#  [   0 4000]]
# sensitivity: 0.9998
# specificity: 1.0000
