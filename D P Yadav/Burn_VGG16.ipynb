# %%
import tensorflow as tf
from tensorflow import keras
# %matplotlib inline
import numpy as np
import pickle
import cv2
from os import listdir
from sklearn.preprocessing import LabelBinarizer
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
import tensorflow as tf
import gc
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import VGG16, DenseNet169
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout, GlobalAveragePooling2D, Activation, BatchNormalization, Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,TensorBoard,TerminateOnNaN, LearningRateScheduler
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TerminateOnNaN
from tensorflow.keras.layers import Lambda, Reshape, DepthwiseConv2D, ZeroPadding2D, Add, MaxPooling2D,Activation, Flatten, Conv2D, Dense, Input, Dropout, Concatenate, GlobalMaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras import backend as K

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split, StratifiedKFold, RepeatedStratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, roc_auc_score, roc_curve, auc
from imutils import paths
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import shutil
import cv2
import os
#from classification_models.tfkeras import Classifiers
from datetime import datetime
# %load_ext tensorboard

# %%
class MyCustomCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}): 
        if(logs.get('acc') >= 0.96):   
            print("Reached 95% accuracy so cancelling training!")
            self.model.stop_training = True

# %%
EPOCHS =1
INIT_LR = 3e-3
BS =32
default_image_size = tuple((224, 224))
image_size = 0
width=224
height=224
depth=3
train_dir=r"D:\DP\Burn_Aug"
#valid_dir=r"C:\Users\Glau\Desktop\DP\Pediastrum_cnn\Test"
train_folder=listdir(train_dir)
#valid_folder=listdir(valid_dir)

# %%
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, default_image_size)   
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
train_image_list, train_image_label=[],[]
for disease_folder in train_folder:
    print(f"processing {disease_folder} ...")
    disease_img_folder= listdir(f"{train_dir}/{disease_folder}")
    #print(disease_img_folder)
    for disease_img in disease_img_folder:
    #for disease_img in disease_img_folder[: : 2]:    
        image_directory = f"{train_dir}/{disease_folder}/{disease_img}"
        if image_directory.endswith(".jpeg") == True or image_directory.endswith(".jpg") == True or  image_directory.endswith(".png") == True:
            train_image_list.append(convert_image_to_array(image_directory))
            train_image_label.append(disease_folder)
print("[INFO] Image loading completed")
# Out:
# processing dd ...
# processing ft ...
# processing sd ...
# [INFO] Image loading completed

# %%
print(len(train_image_label))
# Out:
# 6000

# %%
label_binarizer = LabelBinarizer()
bin_train_image_labels = label_binarizer.fit_transform(train_image_label)
#bin_valid_image_labels = label_binarizer.fit_transform(valid_image_label)
pickle.dump(label_binarizer,open('Label_Instance_burn_label_VGG16.pk', 'wb'))
n_classes = len(label_binarizer.classes_)

# %%
print(len(bin_train_image_labels))
# Out:
# 6000

# %%
np_train_image_list = np.array(train_image_list, dtype=np.float32) / 255.0

# %%
opt = Adam(lr=INIT_LR, decay=INIT_LR / EPOCHS)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,classification_report 
from sklearn.metrics import precision_score 
from sklearn.metrics import recall_score 
from sklearn.metrics import f1_score 
from sklearn.metrics import cohen_kappa_score 
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import Normalizer

# %%
from keras.layers import Input, Conv2D, MaxPooling2D
from keras.layers import Dense, Flatten
from keras.models import Model

_input = Input((224,224,3)) 

conv1  = Conv2D(filters=64, kernel_size=(7,7), padding="same", activation="relu")(_input)
conv2  = Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu")(conv1)
pool1  = MaxPooling2D((2, 2))(conv2)

conv3  = Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu")(pool1)
conv4  = Conv2D(filters=64, kernel_size=(3,3), padding="same", activation="relu")(conv3)
pool2  = MaxPooling2D((2, 2))(conv4)

conv5  = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(pool2)
conv6  = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(conv5)
conv7  = Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu")(conv6)
pool3  = MaxPooling2D((2, 2))(conv7)

conv8  = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(pool3)
conv9  = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(conv8)
conv10 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(conv9)
pool4  = MaxPooling2D((2, 2))(conv10)

conv11 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(pool4)
conv12 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(conv11)
conv13 = Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu")(conv12)
pool5  = MaxPooling2D((2, 2))(conv13)

flat   = Flatten()(pool5)
dense1 = Dense(4096, activation="relu")(flat)
dense2 = Dense(4096, activation="relu")(dense1)
output = Dense(3, activation="softmax")(dense1)


model  = Model(inputs=_input, outputs=output)

# %%
#ALEXNET
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np
np.random.seed(1000)
#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
#model.add(Dense(1000))
#model.add(Activation('relu'))
# Add Dropout
#model.add(Dropout(0.4))

# Output Layer
model.add(Dense(1))
model.add(Activation('softmax'))

model.summary()

# Compile the model
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=opt, metrics=["accuracy"])

# %%
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

print("[INFO] training network...")
# Out:
# [INFO] training network...

# %%
conf_matrix_list_of_arrays = []
#loss_per_fold = []
seed = 13   # for reproducibility you can change it. 
np.random.seed(seed)
roundlabel=[]
test=[]
idtest=[]
x_validate=[]
kfold = KFold(5, True, seed)
for train_idx, val_idx in kfold.split(np_train_image_list, y=bin_train_image_labels):
    #print('train: %s, val: %s' % (train_idx, val_idx))
    x_train, x_val = np_train_image_list[train_idx], np_train_image_list[val_idx]
    y_train, y_val= bin_train_image_labels[train_idx], bin_train_image_labels[val_idx]
    history=model.fit(x_train, y_train,
                  validation_data=(x_val, y_val),
                  batch_size=BS,
                  epochs=EPOCHS, verbose=1        
                  )
    ycalculated = model.predict(x_val)
    yhat_classes =np.argmax(ycalculated,axis=1)
    rounded_labels=np.argmax(y_val,axis=1)                           
    conf_matrix = confusion_matrix(rounded_labels,yhat_classes)
    conf_matrix_list_of_arrays .append(conf_matrix)
    #roundlabel.append(rounded_labels)
   # test.append(yhat_classes)
   # idtest.append(val_idx)
# Out:
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/1
# 4800/4800 [==============================] - 57s 12ms/step - loss: 1.5451 - accuracy: 0.3269 - val_loss: 1.0987 - val_accuracy: 0.3258
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/1
# 4800/4800 [==============================] - 57s 12ms/step - loss: 1.0987 - accuracy: 0.3302 - val_loss: 1.0988 - val_accuracy: 0.3292
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/1
# 4800/4800 [==============================] - 57s 12ms/step - loss: 1.0987 - accuracy: 0.3229 - val_loss: 1.0986 - val_accuracy: 0.3283
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/1
# 4800/4800 [==============================] - 57s 12ms/step - loss: 1.0987 - accuracy: 0.3271 - val_loss: 1.0987 - val_accuracy: 0.3200
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/1
# 4800/4800 [==============================] - 57s 12ms/step - loss: 1.0987 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3358
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1  - Accuracy: [[  0   0 393]
#  [  0   0 416]
#  [  0   0 391]]%
# ------------------------------------------------------------------------
# > Fold 2  - Accuracy: [[  0   0 419]
#  [  0   0 386]
#  [  0   0 395]]%
# ------------------------------------------------------------------------
# > Fold 3  - Accuracy: [[  0 402   0]
#  [  0 394   0]
#  [  0 404   0]]%
# ------------------------------------------------------------------------
# > Fold 4  - Accuracy: [[  0 409   0]
#  [  0 384   0]
#  [  0 407   0]]%
# ------------------------------------------------------------------------
# > Fold 5  - Accuracy: [[  0   0 377]
#  [  0   0 420]
#  [  0   0 403]]%

# %%
print(conf_matrix_list_of_arrays[0])
# Out:
# [[  0   0 393]
#  [  0   0 416]
#  [  0   0 391]]

# %%
import numpy as np

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 'xx-large')

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
for i in range(5):
    plot_confusion_matrix(conf_matrix_list_of_arrays[i], 
                      normalize = False,
                      target_names = ['Deep-Dermal', 'Full-Thickness', 'Superficial-Dermal'],
                      title        = "Confusion Matrix")

# %%
from sklearn.metrics import accuracy_score,classification_report 
target_names = ['Deep-Dermal', 'Full-Thickness', 'Superficial-Dermal']
print(classification_report(rounded_labels, yhat_classes, target_names=target_names))
# Out:
#                     precision    recall  f1-score   support
#
#        Deep-Dermal       0.31      1.00      0.48       377
#     Full-Thickness       0.00      0.00      0.00       420
# Superficial-Dermal       0.00      0.00      0.00       403
#
#           accuracy                           0.31      1200
#          macro avg       0.10      0.33      0.16      1200
#       weighted avg       0.10      0.31      0.15      1200
# C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
class_to_label_map={0:'Deep-Dermal', 1:'Full-Thickness', 2:'Superficial-Dermal' }

# %%
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle

n_classes =3

from sklearn.metrics import roc_curve, auc

# Plot linewidth.
lw = 2
lb = LabelBinarizer()
lb.fit(rounded_labels)
y_test= lb.transform(rounded_labels)
snn_pred = lb.transform(yhat_classes)
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], snn_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), snn_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes-97), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], class_to_label_map[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw,color='white')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of Cell')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'g', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accurarcy')
plt.title('Training and Validation Accurarcy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import numpy as np
np.random.seed(1000)
#Instantiate an empty model
model = Sequential()

# 1st Convolutional Layer
model.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# 2nd Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(11,11), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# 3rd Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 4th Convolutional Layer
model.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))

# 5th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='valid'))
model.add(Activation('relu'))
# Max Pooling
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'))

# Passing it to a Fully Connected layer
model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(4096, input_shape=(224*224*3,)))
model.add(Activation('relu'))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# 2nd Fully Connected Layer
model.add(Dense(4096))
model.add(Activation('relu'))
# Add Dropout
model.add(Dropout(0.4))

# 3rd Fully Connected Layer
#model.add(Dense(1000))
#model.add(Activation('relu'))
# Add Dropout
#model.add(Dropout(0.4))

# Output Layer
model.add(Dense(3))
model.add(Activation('softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 54, 54, 96)        34944
# _________________________________________________________________
# activation_1 (Activation)    (None, 54, 54, 96)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 27, 27, 96)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 17, 17, 256)       2973952
# _________________________________________________________________
# activation_2 (Activation)    (None, 17, 17, 256)       0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 6, 6, 384)         885120
# _________________________________________________________________
# activation_3 (Activation)    (None, 6, 6, 384)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 4, 384)         1327488
# _________________________________________________________________
# activation_4 (Activation)    (None, 4, 4, 384)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 2, 2, 256)         884992
# _________________________________________________________________
# activation_5 (Activation)    (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              1052672
# _________________________________________________________________
# activation_6 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# activation_7 (Activation)    (None, 4096)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 12291
# _________________________________________________________________
# activation_8 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 23,952,771
# Trainable params: 23,952,771
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

print("[INFO] training network...")
# Out:
# [INFO] training network...

# %%
conf_matrix_list_of_arrays = []
#loss_per_fold = []
seed = 13   # for reproducibility you can change it. 
np.random.seed(seed)
roundlabel=[]
test=[]
idtest=[]
x_validate=[]
kfold = KFold(5, True, seed)
for train_idx, val_idx in kfold.split(np_train_image_list, y=bin_train_image_labels):
    #print('train: %s, val: %s' % (train_idx, val_idx))
    x_train, x_val = np_train_image_list[train_idx], np_train_image_list[val_idx]
    y_train, y_val= bin_train_image_labels[train_idx], bin_train_image_labels[val_idx]
    history=model.fit(x_train, y_train,
                  validation_data=(x_val, y_val),
                  batch_size=BS,
                  epochs=EPOCHS, verbose=1        
                  )
    ycalculated = model.predict(x_val)
    yhat_classes =np.argmax(ycalculated,axis=1)
    rounded_labels=np.argmax(y_val,axis=1)                           
    conf_matrix = confusion_matrix(rounded_labels,yhat_classes)
    conf_matrix_list_of_arrays .append(conf_matrix)
    roundlabel.append(rounded_labels)
    test.append(yhat_classes)
    idtest.append(val_idx)
    
print('Score per fold')
for i in range(0, len(conf_matrix_list_of_arrays)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1}  - Accuracy: {conf_matrix_list_of_arrays[i]}%')
# Out:
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 8s 2ms/step - loss: 7.4657 - accuracy: 0.3340 - val_loss: 1.0999 - val_accuracy: 0.3258
# Epoch 2/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0998 - accuracy: 0.3200 - val_loss: 1.0994 - val_accuracy: 0.3258
# Epoch 3/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3448 - val_loss: 1.0986 - val_accuracy: 0.3467
# Epoch 4/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0993 - accuracy: 0.3317 - val_loss: 1.0992 - val_accuracy: 0.3258
# Epoch 5/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3462 - val_loss: 1.0989 - val_accuracy: 0.3258
# Epoch 6/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0990 - accuracy: 0.3429 - val_loss: 1.0984 - val_accuracy: 0.3467
# Epoch 7/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0996 - accuracy: 0.3223 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 8/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0993 - accuracy: 0.3285 - val_loss: 1.0990 - val_accuracy: 0.3258
# Epoch 9/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3256 - val_loss: 1.0987 - val_accuracy: 0.3258
# Epoch 10/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0989 - accuracy: 0.3319 - val_loss: 1.0990 - val_accuracy: 0.3258
# Epoch 11/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0991 - accuracy: 0.3262 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 12/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0990 - accuracy: 0.3235 - val_loss: 1.0987 - val_accuracy: 0.3258
# Epoch 13/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3292 - val_loss: 1.0987 - val_accuracy: 0.3258
# Epoch 14/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3338 - val_loss: 1.0990 - val_accuracy: 0.3258
# Epoch 15/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0989 - accuracy: 0.3375 - val_loss: 1.0989 - val_accuracy: 0.3258
# Epoch 16/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3390 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 17/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3306 - val_loss: 1.0988 - val_accuracy: 0.3258
# Epoch 18/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0990 - accuracy: 0.3215 - val_loss: 1.0987 - val_accuracy: 0.3258
# Epoch 19/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0989 - accuracy: 0.3242 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 20/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0989 - accuracy: 0.3242 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 21/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3402 - val_loss: 1.0989 - val_accuracy: 0.3275
# Epoch 22/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0988 - accuracy: 0.3292 - val_loss: 1.0989 - val_accuracy: 0.3275
# Epoch 23/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0990 - accuracy: 0.3202 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 24/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3288 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 25/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3360 - val_loss: 1.0989 - val_accuracy: 0.3258
# Epoch 26/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3308 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 27/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3306 - val_loss: 1.0988 - val_accuracy: 0.3258
# Epoch 28/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3383 - val_loss: 1.0989 - val_accuracy: 0.3258
# Epoch 29/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3288 - val_loss: 1.0990 - val_accuracy: 0.3258
# Epoch 30/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3388 - val_loss: 1.0991 - val_accuracy: 0.3258
# Epoch 31/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3352 - val_loss: 1.0987 - val_accuracy: 0.3258
# Epoch 32/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3304 - val_loss: 1.0987 - val_accuracy: 0.3258
# Epoch 33/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0989 - accuracy: 0.3246 - val_loss: 1.0988 - val_accuracy: 0.3258
# Epoch 34/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3300 - val_loss: 1.0988 - val_accuracy: 0.3258
# Epoch 35/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3227 - val_loss: 1.0986 - val_accuracy: 0.3258
# Epoch 36/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 37/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3335 - val_loss: 1.0988 - val_accuracy: 0.3258
# Epoch 38/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0990 - val_accuracy: 0.3258
# Epoch 39/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3375 - val_loss: 1.0990 - val_accuracy: 0.3258
# Epoch 40/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3310 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 41/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0988 - accuracy: 0.3306 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 42/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3350 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 43/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0989 - accuracy: 0.3285 - val_loss: 1.0987 - val_accuracy: 0.3275
# Epoch 44/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3365 - val_loss: 1.0989 - val_accuracy: 0.3275
# Epoch 45/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0988 - accuracy: 0.3273 - val_loss: 1.0989 - val_accuracy: 0.3258
# Epoch 46/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3281 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 47/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3260 - val_loss: 1.0988 - val_accuracy: 0.3275
# Epoch 48/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0988 - accuracy: 0.3277 - val_loss: 1.0989 - val_accuracy: 0.3275
# Epoch 49/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3277 - val_loss: 1.0989 - val_accuracy: 0.3258
# Epoch 50/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3275 - val_loss: 1.0989 - val_accuracy: 0.3258
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3290 - val_loss: 1.0987 - val_accuracy: 0.3292
# Epoch 2/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3329 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 3/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3281 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 4/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3252 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 5/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3321 - val_loss: 1.0989 - val_accuracy: 0.3292
# Epoch 6/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3321 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 7/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3352 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 8/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3262 - val_loss: 1.0989 - val_accuracy: 0.3292
# Epoch 9/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3290 - val_loss: 1.0990 - val_accuracy: 0.3292
# Epoch 10/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3313 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 11/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3275 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 12/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3383 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 13/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3335 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 14/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0988 - accuracy: 0.3244 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 15/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3310 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 16/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3344 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 17/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3433 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 18/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3346 - val_loss: 1.0990 - val_accuracy: 0.3292
# Epoch 19/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3352 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 20/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3346 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 21/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3383 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 22/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3300 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 23/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3317 - val_loss: 1.0989 - val_accuracy: 0.3292
# Epoch 24/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3360 - val_loss: 1.0988 - val_accuracy: 0.3217
# Epoch 25/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3273 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 26/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3371 - val_loss: 1.0991 - val_accuracy: 0.3217
# Epoch 27/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3281 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 28/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3325 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 29/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3329 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 30/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3369 - val_loss: 1.0988 - val_accuracy: 0.3217
# Epoch 31/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3215 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 32/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3365 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 33/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3302 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 34/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3254 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 35/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3296 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 36/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3344 - val_loss: 1.0991 - val_accuracy: 0.3217
# Epoch 37/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3310 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 38/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3350 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 39/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3363 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 40/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3315 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 41/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3363 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 42/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3346 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 43/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3331 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 44/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3329 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 45/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3350 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 46/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3269 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 47/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3244 - val_loss: 1.0989 - val_accuracy: 0.3217
# Epoch 48/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3294 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 49/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3363 - val_loss: 1.0990 - val_accuracy: 0.3217
# Epoch 50/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3350 - val_loss: 1.0990 - val_accuracy: 0.3217
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3319 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 2/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3356 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 3/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3269 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 4/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0988 - accuracy: 0.3348 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 5/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3165 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 6/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3254 - val_loss: 1.0986 - val_accuracy: 0.3367
# Epoch 7/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3342 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 8/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3258 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 9/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 10/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3294 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 11/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3317 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 12/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3256 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 13/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3338 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 14/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 15/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 16/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 17/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3156 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 18/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3267 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 19/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 20/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3292 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 21/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 22/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3240 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 23/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 24/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 25/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3292 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 26/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3290 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 27/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3288 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 28/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 29/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3352 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 30/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 31/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 32/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3294 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 33/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3273 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 34/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3196 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 35/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 36/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3237 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 37/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3292 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 38/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 39/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 40/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3283 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 41/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3223 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 42/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3240 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 43/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3319 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 44/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 45/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3267 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 46/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3310 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 47/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3281 - val_loss: 1.0987 - val_accuracy: 0.3283
# Epoch 48/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3231 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 49/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3262 - val_loss: 1.0986 - val_accuracy: 0.3283
# Epoch 50/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3346 - val_loss: 1.0986 - val_accuracy: 0.3283
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3319 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 2/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3288 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 3/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 4/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 5/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 6/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 7/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 8/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 9/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 10/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 11/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 12/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 13/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 14/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 15/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 16/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 17/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 18/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 19/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 20/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 21/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 22/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 23/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 24/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 25/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 26/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 27/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 28/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 29/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 30/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 31/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 32/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 33/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 34/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 35/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 36/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 37/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 38/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 39/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 40/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 41/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 42/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 43/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 44/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 45/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 46/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 47/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Epoch 48/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 49/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0988 - val_accuracy: 0.3200
# Epoch 50/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3367 - val_loss: 1.0989 - val_accuracy: 0.3200
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0987 - accuracy: 0.3292 - val_loss: 1.0985 - val_accuracy: 0.3500
# Epoch 2/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3331 - val_loss: 1.0988 - val_accuracy: 0.3142
# Epoch 3/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0989 - val_accuracy: 0.3142
# Epoch 4/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0989 - val_accuracy: 0.3142
# Epoch 5/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0990 - val_accuracy: 0.3142
# Epoch 6/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 7/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 8/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 9/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 10/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 11/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 12/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 13/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 14/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 15/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 16/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 17/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 18/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 19/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 20/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 21/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 22/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 23/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 24/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 25/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0987 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 26/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 27/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0993 - val_accuracy: 0.3142
# Epoch 28/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 29/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 30/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 31/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 32/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 33/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 34/50
# 4800/4800 [==============================] - 7s 2ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 35/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 36/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 37/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0993 - val_accuracy: 0.3142
# Epoch 38/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 39/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 40/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 41/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 42/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 43/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 44/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 45/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Epoch 46/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 47/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 48/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 49/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0991 - val_accuracy: 0.3142
# Epoch 50/50
# 4800/4800 [==============================] - 7s 1ms/step - loss: 1.0986 - accuracy: 0.3381 - val_loss: 1.0992 - val_accuracy: 0.3142
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1  - Accuracy: [[  0   0 393]
#  [  0   0 416]
#  [  0   0 391]]%
# ------------------------------------------------------------------------
# > Fold 2  - Accuracy: [[  0 419   0]
#  [  0 386   0]
#  [  0 395   0]]%
# ------------------------------------------------------------------------
# > Fold 3  - Accuracy: [[  0 402   0]
#  [  0 394   0]
#  [  0 404   0]]%
# ------------------------------------------------------------------------
# > Fold 4  - Accuracy: [[  0 409   0]
#  [  0 384   0]
#  [  0 407   0]]%
# ------------------------------------------------------------------------
# > Fold 5  - Accuracy: [[377   0   0]
#  [420   0   0]
#  [403   0   0]]%

# %%
import numpy as np

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 'xx-large')

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
for i in range(5):
    plot_confusion_matrix(conf_matrix_list_of_arrays[i], 
                      normalize = False,
                      target_names = ['Deep-Dermal', 'Full-Thickness', 'Superficial-Dermal'],
                      title        = "Confusion Matrix")

# %%
from sklearn.metrics import accuracy_score,classification_report 
target_names = ['Deep-Dermal', 'Full-Thickness', 'Superficial-Dermal']
print(classification_report(rounded_labels, yhat_classes, target_names=target_names))
# Out:
#                     precision    recall  f1-score   support
#
#        Deep-Dermal       0.31      1.00      0.48       377
#     Full-Thickness       0.00      0.00      0.00       420
# Superficial-Dermal       0.00      0.00      0.00       403
#
#           accuracy                           0.31      1200
#          macro avg       0.10      0.33      0.16      1200
#       weighted avg       0.10      0.31      0.15      1200
# C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
class_to_label_map={0:'Deep-Dermal', 1:'Full-Thickness', 2:'Superficial-Dermal' }

# %%
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle

n_classes =3

from sklearn.metrics import roc_curve, auc

# Plot linewidth.
lw = 2
lb = LabelBinarizer()
lb.fit(rounded_labels)
y_test= lb.transform(rounded_labels)
snn_pred = lb.transform(yhat_classes)
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], snn_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), snn_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes-97), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], class_to_label_map[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw,color='white')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of Cell')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'g', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accurarcy')
plt.title('Training and Validation Accurarcy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
"""


Clean and simple Keras implementation of network architectures described in:


    - (ResNet-50) [Deep Residual Learning for Image Recognition](https://arxiv.org/pdf/1512.03385.pdf).


    - (ResNeXt-50 32x4d) [Aggregated Residual Transformations for Deep Neural Networks](https://arxiv.org/pdf/1611.05431.pdf).


Python 3.

"""

from tensorflow.keras import layers
from tensorflow.keras import models
#
# image dimensions
#
img_height = 224
img_width = 224
img_channels = 3
#
# network params
#
cardinality = 32
d = 4  # bottleneck width
def residual_network(x, architecture='ResNet'):

    if architecture.lower() == 'resnet':

        channel_scale_factor = 2

        grouped = False

    elif architecture.lower() == 'resnext':

        channel_scale_factor = 1

        grouped = True

    else:
        assert False, 'Invalid architecture specified. Must be one of { \'ResNet\', \'ResNeXt\' }.'
    def add_common_layers(y):

        y = layers.BatchNormalization()(y)

        y = layers.LeakyReLU()(y)
        return y

    def grouped_convolution(y, nb_channels, _strides):

        assert not nb_channels % cardinality

        _d = nb_channels // cardinality

        # in a grouped convolution layer, input and output channels are divided into `cardinality` groups,
        # and convolutions are separately performed within each group
        groups = []
        for j in range(cardinality):
            group = layers.Lambda(lambda z: z[:, :, :, j * _d:j * _d + _d])(y)
            groups.append(layers.Conv2D(_d, kernel_size=(3, 3), strides=_strides, padding='same')(group))
        # the grouped convolutional layer concatenates them as the outputs of the layer
        y = layers.concatenate(groups)
        return y
    def residual_block(y, nb_channels_in, nb_channels_out, _strides=(1, 1), _project_shortcut=False, _grouped=False):

        """
        Our network consists of a stack of residual blocks. These blocks have the same topology,
        and are subject to two simple rules:
        - If producing spatial maps of the same size, the blocks share the same hyper-parameters (width and filter sizes).
        - Each time the spatial map is down-sampled by a factor of 2, the width of the blocks is multiplied by a factor of 2.
        """
        shortcut = y

      # we modify the residual building block as a bottleneck design to make the network more economical

        y = layers.Conv2D(nb_channels_in, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)

        y = add_common_layers(y)
        if not _grouped:
            # ResNet
            y = layers.Conv2D(nb_channels_in, kernel_size=(3, 3), strides=_strides, padding='same')(y)
        else:
            # ResNeXt
            y = grouped_convolution(y, nb_channels_in, _strides=_strides)
        y = add_common_layers(y)

        y = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=(1, 1), padding='same')(y)
       # batch normalization is employed after aggregating the transformations and before adding to the shortcut
        y = layers.BatchNormalization()(y)

        # identity shortcuts used directly when the input and output are of the same dimensions
        if _project_shortcut or _strides != (1, 1):
            # when the dimensions increase projection shortcut is used to match dimensions (done by 1×1 convolutions

            # when the shortcuts go across feature maps of two sizes, they are performed with a stride of 2
            shortcut = layers.Conv2D(nb_channels_out, kernel_size=(1, 1), strides=_strides, padding='same')(shortcut)
            shortcut = layers.BatchNormalization()(shortcut)
        y = layers.add([shortcut, y])

        # relu is performed right after each batch normalization

        # expect for the output of the block where relu is performed after the adding to the shortcut

        y = layers.LeakyReLU()(y)

        return y
    # conv1
    x = layers.Conv2D(32, kernel_size=(7, 7), strides=(2, 2), padding='same')(x)
    x = add_common_layers(x)
  # conv2
    x = layers.MaxPool2D(pool_size=(3, 3), strides=(2, 2), padding='same')(x)

    for i in range(3):
        project_shortcut = True if i == 0 else False
        x = residual_block(x, 32 // channel_scale_factor, 64, _project_shortcut=project_shortcut, _grouped=grouped)
    # conv3
    for i in range(4):
        # down-sampling is performed by conv3_1, conv4_1, and conv5_1 with a stride of 2
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 128 // channel_scale_factor, 256, _strides=strides, _grouped=grouped)
    # conv4
    for i in range(6):
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 256 // channel_scale_factor, 1024, _strides=strides, _grouped=grouped)
    # conv5
    for i in range(3):
        strides = (2, 2) if i == 0 else (1, 1)
        x = residual_block(x, 1024 // channel_scale_factor, 2048, _strides=strides, _grouped=grouped)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(3)(x)
    return x
image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
network_output = residual_network(image_tensor, architecture='ResNeXt')





model = models.Model(inputs=[image_tensor], outputs=[network_output])
print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 32) 4736        input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 112, 112, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 112, 112, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 32)   0           leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 32)   1056        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 56, 56, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 56, 56, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 1)    10          lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 56, 56, 1)    10          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 1)    10          lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 1)    10          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 1)    10          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 1)    10          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 1)    10          lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 1)    10          lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 56, 56, 1)    10          lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 56, 56, 1)    10          lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 1)    10          lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 1)    10          lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 1)    10          lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 1)    10          lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 1)    10          lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 1)    10          lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 1)    10          lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 1)    10          lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 1)    10          lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 1)    10          lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 56, 56, 1)    10          lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 56, 56, 1)    10          lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 56, 56, 1)    10          lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 56, 56, 1)    10          lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 56, 56, 1)    10          lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 56, 56, 1)    10          lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 56, 56, 1)    10          lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 56, 56, 1)    10          lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 56, 56, 1)    10          lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 56, 56, 1)    10          lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 56, 56, 1)    10          lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 56, 56, 1)    10          lambda_31[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 56, 56, 32)   0           conv2d_2[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 56, 56, 32)   128         concatenate[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 56, 56, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 56, 56, 64)   2112        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 56, 56, 64)   2112        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 56, 56, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 56, 56, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 56, 56, 64)   0           batch_normalization_4[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 56, 56, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 56, 56, 32)   2080        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 56, 56, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 56, 56, 1)    10          lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 56, 56, 1)    10          lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 56, 56, 1)    10          lambda_34[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 56, 56, 1)    10          lambda_35[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 56, 56, 1)    10          lambda_36[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 56, 56, 1)    10          lambda_37[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 56, 56, 1)    10          lambda_38[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 56, 56, 1)    10          lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 56, 56, 1)    10          lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 56, 56, 1)    10          lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 56, 56, 1)    10          lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 56, 56, 1)    10          lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 56, 56, 1)    10          lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 56, 56, 1)    10          lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 1)    10          lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 1)    10          lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 56, 56, 1)    10          lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 56, 56, 1)    10          lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 56, 56, 1)    10          lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 56, 56, 1)    10          lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 56, 56, 1)    10          lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 56, 56, 1)    10          lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 56, 56, 1)    10          lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 56, 56, 1)    10          lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 1)    10          lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 1)    10          lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 1)    10          lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 1)    10          lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 56, 56, 1)    10          lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 56, 56, 1)    10          lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 56, 56, 1)    10          lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 56, 56, 1)    10          lambda_63[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 32)   0           conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 32)   128         concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 56, 56, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 56, 56, 64)   2112        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 64)   256         conv2d_69[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 56, 56, 64)   0           leaky_re_lu_3[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 56, 56, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 56, 56, 32)   2080        leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 32)   128         conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 56, 56, 32)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 56, 56, 1)    0           leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 56, 56, 1)    10          lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 56, 56, 1)    10          lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 56, 56, 1)    10          lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 56, 56, 1)    10          lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 56, 56, 1)    10          lambda_68[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 56, 56, 1)    10          lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 56, 56, 1)    10          lambda_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 56, 56, 1)    10          lambda_71[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 56, 56, 1)    10          lambda_72[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 56, 56, 1)    10          lambda_73[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 56, 56, 1)    10          lambda_74[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 56, 56, 1)    10          lambda_75[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 56, 56, 1)    10          lambda_76[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 56, 56, 1)    10          lambda_77[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 56, 56, 1)    10          lambda_78[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 56, 56, 1)    10          lambda_79[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 56, 56, 1)    10          lambda_80[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 56, 56, 1)    10          lambda_81[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 56, 56, 1)    10          lambda_82[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_490 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_491 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_492 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_493 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_494 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_495 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_496 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_497 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_498 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_499 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_500 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_501 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_502 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_503 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_504 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_505 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_506 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_507 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_508 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_509 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_510 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# lambda_511 (Lambda)             (None, 7, 7, 32)     0           leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_516 (Conv2D)             (None, 7, 7, 32)     9248        lambda_480[0][0]
# __________________________________________________________________________________________________
# conv2d_517 (Conv2D)             (None, 7, 7, 32)     9248        lambda_481[0][0]
# __________________________________________________________________________________________________
# conv2d_518 (Conv2D)             (None, 7, 7, 32)     9248        lambda_482[0][0]
# __________________________________________________________________________________________________
# conv2d_519 (Conv2D)             (None, 7, 7, 32)     9248        lambda_483[0][0]
# __________________________________________________________________________________________________
# conv2d_520 (Conv2D)             (None, 7, 7, 32)     9248        lambda_484[0][0]
# __________________________________________________________________________________________________
# conv2d_521 (Conv2D)             (None, 7, 7, 32)     9248        lambda_485[0][0]
# __________________________________________________________________________________________________
# conv2d_522 (Conv2D)             (None, 7, 7, 32)     9248        lambda_486[0][0]
# __________________________________________________________________________________________________
# conv2d_523 (Conv2D)             (None, 7, 7, 32)     9248        lambda_487[0][0]
# __________________________________________________________________________________________________
# conv2d_524 (Conv2D)             (None, 7, 7, 32)     9248        lambda_488[0][0]
# __________________________________________________________________________________________________
# conv2d_525 (Conv2D)             (None, 7, 7, 32)     9248        lambda_489[0][0]
# __________________________________________________________________________________________________
# conv2d_526 (Conv2D)             (None, 7, 7, 32)     9248        lambda_490[0][0]
# __________________________________________________________________________________________________
# conv2d_527 (Conv2D)             (None, 7, 7, 32)     9248        lambda_491[0][0]
# __________________________________________________________________________________________________
# conv2d_528 (Conv2D)             (None, 7, 7, 32)     9248        lambda_492[0][0]
# __________________________________________________________________________________________________
# conv2d_529 (Conv2D)             (None, 7, 7, 32)     9248        lambda_493[0][0]
# __________________________________________________________________________________________________
# conv2d_530 (Conv2D)             (None, 7, 7, 32)     9248        lambda_494[0][0]
# __________________________________________________________________________________________________
# conv2d_531 (Conv2D)             (None, 7, 7, 32)     9248        lambda_495[0][0]
# __________________________________________________________________________________________________
# conv2d_532 (Conv2D)             (None, 7, 7, 32)     9248        lambda_496[0][0]
# __________________________________________________________________________________________________
# conv2d_533 (Conv2D)             (None, 7, 7, 32)     9248        lambda_497[0][0]
# __________________________________________________________________________________________________
# conv2d_534 (Conv2D)             (None, 7, 7, 32)     9248        lambda_498[0][0]
# __________________________________________________________________________________________________
# conv2d_535 (Conv2D)             (None, 7, 7, 32)     9248        lambda_499[0][0]
# __________________________________________________________________________________________________
# conv2d_536 (Conv2D)             (None, 7, 7, 32)     9248        lambda_500[0][0]
# __________________________________________________________________________________________________
# conv2d_537 (Conv2D)             (None, 7, 7, 32)     9248        lambda_501[0][0]
# __________________________________________________________________________________________________
# conv2d_538 (Conv2D)             (None, 7, 7, 32)     9248        lambda_502[0][0]
# __________________________________________________________________________________________________
# conv2d_539 (Conv2D)             (None, 7, 7, 32)     9248        lambda_503[0][0]
# __________________________________________________________________________________________________
# conv2d_540 (Conv2D)             (None, 7, 7, 32)     9248        lambda_504[0][0]
# __________________________________________________________________________________________________
# conv2d_541 (Conv2D)             (None, 7, 7, 32)     9248        lambda_505[0][0]
# __________________________________________________________________________________________________
# conv2d_542 (Conv2D)             (None, 7, 7, 32)     9248        lambda_506[0][0]
# __________________________________________________________________________________________________
# conv2d_543 (Conv2D)             (None, 7, 7, 32)     9248        lambda_507[0][0]
# __________________________________________________________________________________________________
# conv2d_544 (Conv2D)             (None, 7, 7, 32)     9248        lambda_508[0][0]
# __________________________________________________________________________________________________
# conv2d_545 (Conv2D)             (None, 7, 7, 32)     9248        lambda_509[0][0]
# __________________________________________________________________________________________________
# conv2d_546 (Conv2D)             (None, 7, 7, 32)     9248        lambda_510[0][0]
# __________________________________________________________________________________________________
# conv2d_547 (Conv2D)             (None, 7, 7, 32)     9248        lambda_511[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 7, 7, 1024)   0           conv2d_516[0][0]
#                                                                  conv2d_517[0][0]
#                                                                  conv2d_518[0][0]
#                                                                  conv2d_519[0][0]
#                                                                  conv2d_520[0][0]
#                                                                  conv2d_521[0][0]
#                                                                  conv2d_522[0][0]
#                                                                  conv2d_523[0][0]
#                                                                  conv2d_524[0][0]
#                                                                  conv2d_525[0][0]
#                                                                  conv2d_526[0][0]
#                                                                  conv2d_527[0][0]
#                                                                  conv2d_528[0][0]
#                                                                  conv2d_529[0][0]
#                                                                  conv2d_530[0][0]
#                                                                  conv2d_531[0][0]
#                                                                  conv2d_532[0][0]
#                                                                  conv2d_533[0][0]
#                                                                  conv2d_534[0][0]
#                                                                  conv2d_535[0][0]
#                                                                  conv2d_536[0][0]
#                                                                  conv2d_537[0][0]
#                                                                  conv2d_538[0][0]
#                                                                  conv2d_539[0][0]
#                                                                  conv2d_540[0][0]
#                                                                  conv2d_541[0][0]
#                                                                  conv2d_542[0][0]
#                                                                  conv2d_543[0][0]
#                                                                  conv2d_544[0][0]
#                                                                  conv2d_545[0][0]
#                                                                  conv2d_546[0][0]
#                                                                  conv2d_547[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 7, 7, 1024)   4096        concatenate_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 7, 7, 1024)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_548 (Conv2D)             (None, 7, 7, 2048)   2099200     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 7, 7, 2048)   8192        conv2d_548[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           leaky_re_lu_45[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            6147        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 18,272,291
# Trainable params: 18,217,571
# Non-trainable params: 54,720
# __________________________________________________________________________________________________
# None

# %%
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])

print("[INFO] training network...")
# Out:
# [INFO] training network...

# %%
conf_matrix_list_of_arrays = []
#loss_per_fold = []
seed = 13   # for reproducibility you can change it. 
np.random.seed(seed)
roundlabel=[]
test=[]
idtest=[]
x_validate=[]
kfold = KFold(5, True, seed)
for train_idx, val_idx in kfold.split(np_train_image_list, y=bin_train_image_labels):
    #print('train: %s, val: %s' % (train_idx, val_idx))
    x_train, x_val = np_train_image_list[train_idx], np_train_image_list[val_idx]
    y_train, y_val= bin_train_image_labels[train_idx], bin_train_image_labels[val_idx]
    history=model.fit(x_train, y_train,
                  validation_data=(x_val, y_val),
                  batch_size=BS,
                  epochs=EPOCHS, verbose=1        
                  )
    ycalculated = model.predict(x_val)
    yhat_classes =np.argmax(ycalculated,axis=1)
    rounded_labels=np.argmax(y_val,axis=1)                           
    conf_matrix = confusion_matrix(rounded_labels,yhat_classes)
    conf_matrix_list_of_arrays .append(conf_matrix)
    roundlabel.append(rounded_labels)
    test.append(yhat_classes)
    idtest.append(val_idx)
    
print('Score per fold')
for i in range(0, len(conf_matrix_list_of_arrays)):
    print('------------------------------------------------------------------------')
    print(f'> Fold {i+1}  - Accuracy: {conf_matrix_list_of_arrays[i]}%')
# Out:
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 107s 22ms/sample - loss: 5.6874 - accuracy: 0.3306 - val_loss: 5.5963 - val_accuracy: 0.3467
# Epoch 2/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 3/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 4/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 5/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 6/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 7/50
# 4800/4800 [==============================] - 63s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 8/50
# 4800/4800 [==============================] - 63s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 9/50
# 4800/4800 [==============================] - 63s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 10/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 11/50
# 4800/4800 [==============================] - 63s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 12/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 13/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 14/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 15/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 16/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 17/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 18/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 19/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 20/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 21/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 22/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 23/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 24/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 25/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 26/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 27/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 28/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 29/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 30/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 31/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 32/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 33/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 34/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 35/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 36/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 37/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 38/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 39/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 40/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 41/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 42/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 43/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 44/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 45/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 46/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 47/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 48/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 49/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Epoch 50/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3190 - accuracy: 0.3300 - val_loss: 5.5876 - val_accuracy: 0.3467
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 2/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 3/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 4/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 5/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 6/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 7/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 8/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 9/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 10/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 11/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 12/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 13/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 14/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 15/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 16/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 17/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 18/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 19/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 20/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 21/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 22/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 23/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 24/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 25/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 26/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 27/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 28/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 29/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 30/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 31/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 32/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 33/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 34/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 35/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 36/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 37/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 38/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 39/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 40/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 41/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 42/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 43/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 44/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 45/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 46/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 47/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 48/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 49/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Epoch 50/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4197 - accuracy: 0.3363 - val_loss: 5.1847 - val_accuracy: 0.3217
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 2/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 3/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 4/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 5/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 6/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 7/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 8/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 9/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 10/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 11/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 12/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 13/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 14/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 15/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 16/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 17/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 18/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 19/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 20/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 21/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 22/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 23/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 24/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 25/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 26/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 27/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 28/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 29/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 30/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 31/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 32/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 33/50
# 4800/4800 [==============================] - 63s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 34/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 35/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 36/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 37/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 38/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 39/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 40/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 41/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 42/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 43/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 44/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 45/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 46/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 47/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 48/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 49/50
# 4800/4800 [==============================] - 60s 12ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Epoch 50/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3928 - accuracy: 0.3346 - val_loss: 5.2921 - val_accuracy: 0.3283
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 2/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 3/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 4/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 5/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 6/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 7/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 8/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 9/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 10/50
# 4800/4800 [==============================] - 63s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 11/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 12/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 13/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 14/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 15/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 16/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 17/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 18/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 19/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 20/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 21/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 22/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 23/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 24/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 25/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 26/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 27/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 28/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 29/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 30/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 31/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 32/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 33/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 34/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 35/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 36/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 37/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 38/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 39/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 40/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 41/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 42/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 43/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 44/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 45/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 46/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 47/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 48/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 49/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Epoch 50/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.4264 - accuracy: 0.3367 - val_loss: 5.1578 - val_accuracy: 0.3200
# Train on 4800 samples, validate on 1200 samples
# Epoch 1/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 2/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 3/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 4/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 5/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 6/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 7/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 8/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 9/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 10/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 11/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 12/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 13/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 14/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 15/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 16/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 17/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 18/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 19/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 20/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 21/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 22/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 23/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 24/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 25/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 26/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 27/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 28/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 29/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 30/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 31/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 32/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 33/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 34/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 35/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 36/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 37/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 38/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 39/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 40/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 41/50
# 4800/4800 [==============================] - 61s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 42/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 43/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 44/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 45/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 46/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 47/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 48/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 49/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Epoch 50/50
# 4800/4800 [==============================] - 62s 13ms/sample - loss: 5.3055 - accuracy: 0.3292 - val_loss: 5.6413 - val_accuracy: 0.3500
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1  - Accuracy: [[  0 393   0]
#  [  0 416   0]
#  [  0 391   0]]%
# ------------------------------------------------------------------------
# > Fold 2  - Accuracy: [[  0 419   0]
#  [  0 386   0]
#  [  0 395   0]]%
# ------------------------------------------------------------------------
# > Fold 3  - Accuracy: [[  0 402   0]
#  [  0 394   0]
#  [  0 404   0]]%
# ------------------------------------------------------------------------
# > Fold 4  - Accuracy: [[  0 409   0]
#  [  0 384   0]
#  [  0 407   0]]%
# ------------------------------------------------------------------------
# > Fold 5  - Accuracy: [[  0 377   0]
#  [  0 420   0]
#  [  0 403   0]]%

# %%
import numpy as np

def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize = 'xx-large')

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
for i in range(5):
    plot_confusion_matrix(conf_matrix_list_of_arrays[i], 
                      normalize = False,
                      target_names = ['Deep-Dermal', 'Full-Thickness', 'Superficial-Dermal'],
                      title        = "Confusion Matrix")

# %%
from sklearn.metrics import accuracy_score,classification_report 
target_names = ['Deep-Dermal', 'Full-Thickness', 'Superficial-Dermal']
print(classification_report(rounded_labels, yhat_classes, target_names=target_names))
# Out:
#                     precision    recall  f1-score   support
#
#        Deep-Dermal       0.00      0.00      0.00       377
#     Full-Thickness       0.35      1.00      0.52       420
# Superficial-Dermal       0.00      0.00      0.00       403
#
#           accuracy                           0.35      1200
#          macro avg       0.12      0.33      0.17      1200
#       weighted avg       0.12      0.35      0.18      1200
# C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
class_to_label_map={0:'Deep-Dermal', 1:'Full-Thickness', 2:'Superficial-Dermal' }

# %%
from sklearn.datasets import make_classification
from sklearn.preprocessing import label_binarize
from scipy import interp
from itertools import cycle

n_classes =3

from sklearn.metrics import roc_curve, auc

# Plot linewidth.
lw = 2
lb = LabelBinarizer()
lb.fit(rounded_labels)
y_test= lb.transform(rounded_labels)
snn_pred = lb.transform(yhat_classes)
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], snn_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), snn_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area

# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(n_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(n_classes):
    mean_tpr += interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= n_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot all ROC curves
plt.figure(1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(n_classes-97), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()


# Zoom in view of the upper left corner.
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

plt.plot(fpr["macro"], tpr["macro"],
         label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='navy', linestyle=':', linewidth=4)

colors = cycle(['aqua', 'darkorange', 'cornflowerblue'])
for i, color in zip(range(3), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw,
             label='ROC curve (area = %0.2f) for %s' % (roc_auc[i], class_to_label_map[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw,color='white')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic of Cell')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\Glau\.conda\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: scipy.interp is deprecated and will be removed in SciPy 2.0.0, use numpy.interp instead

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'g', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accurarcy')
plt.title('Training and Validation Accurarcy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'g', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
